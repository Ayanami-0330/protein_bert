# %% [markdown]
# # Anti-CRISPR Full Experiment Plan Demo
#
# 本 notebook 按实验编号拆分为独立 cell，覆盖 Stage0~Stage4 的完整实验清单。
#
# - 每个编号实验对应一个独立 cell（名称与编号写在 cell 顶部注释中）
# - 单独包含 RPSSM(110) 在两条线上的额外对照：
#   - PSSM-only：`Ablation_RPSSM_110`
#   - ProteinBERT+PSSM 融合：`Fusion_PSSM110`
# - 流程环环相扣：先做 Stage1（ProteinBERT 本体 head/超参对比）选出最佳个体，再做 Stage2/Stage4 融合对照。

# %%
# Setup: imports, paths, constants
import os
from dataclasses import dataclass
from typing import Dict, List

import numpy as np
import pandas as pd
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import average_precision_score, brier_score_loss, f1_score, matthews_corrcoef, roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow import keras

from proteinbert import (
    OutputSpec,
    OutputType,
    FinetuningModelGenerator,
    FusionTrainConfig,
    attach_pssm_features,
    finetune,
    load_anticrispr_with_ids,
    load_feature_cache,
    load_pretrained_model,
    run_finetune_with_pssm,
)
from proteinbert.conv_and_global_attention_model import get_model_with_hidden_layers_as_outputs

PROJECT_ROOT = '/home/nemophila/projects/protein_bert'
BENCHMARKS_DIR = f'{PROJECT_ROOT}/anticrispr_benchmarks'
WORK_ROOT = f'{PROJECT_ROOT}/pssm_work'
FEATURE_VARIANTS = ['110', '310', '710', '1110']
SEEDS = [0, 11, 22, 33, 44]

# 结果收集容器：key=(Exp, Seed) -> row dict
RESULTS = {}

def record_result(exp: str, seed: int, metrics: Dict[str, float], extra: Dict[str, object] = None):
    row = {'Exp': exp, 'Seed': seed, **metrics}
    if extra:
        row.update(extra)
    RESULTS[(exp, int(seed))] = row

def to_results_df() -> pd.DataFrame:
    if len(RESULTS) == 0:
        return pd.DataFrame(columns=['Exp','Seed','AUC','AUPRC','F1','MCC','Brier','ECE','Threshold'])
    df = pd.DataFrame(list(RESULTS.values()))
    return df.sort_values(['Seed', 'Exp']).reset_index(drop=True)
# Out:
# 2026-02-13 17:37:32.453643: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0

# %%
# Shared helpers: metrics, thresholding, data loading, baseline/fusion runners
def expected_calibration_error(y_true, y_prob, n_bins=10):
    bins = np.linspace(0.0, 1.0, n_bins + 1)
    ids = np.digitize(y_prob, bins) - 1
    ece = 0.0
    n = len(y_true)
    for b in range(n_bins):
        m = ids == b
        if np.any(m):
            conf = float(np.mean(y_prob[m]))
            acc = float(np.mean(y_true[m]))
            ece += (np.sum(m) / n) * abs(acc - conf)
    return float(ece)

def evaluate_binary(y_true, y_prob, thr=0.5):
    y_cls = (y_prob >= thr).astype(int)
    return {
        'AUC': float(roc_auc_score(y_true, y_prob)),
        'AUPRC': float(average_precision_score(y_true, y_prob)),
        'F1': float(f1_score(y_true, y_cls)),
        'MCC': float(matthews_corrcoef(y_true, y_cls)),
        'Brier': float(brier_score_loss(y_true, y_prob)),
        'ECE': float(expected_calibration_error(y_true, y_prob, n_bins=10)),
        'Threshold': float(thr),
    }

def find_best_thr(y_true, y_prob):
    best_thr, best_f1 = 0.5, -1.0
    for thr in np.linspace(0.05, 0.95, 19):
        cur = f1_score(y_true, (y_prob >= thr).astype(int))
        if cur > best_f1:
            best_f1, best_thr = cur, float(thr)
    return best_thr

def load_feature_set(dim: str):
    parquet_path = f'{WORK_ROOT}/features/pssm_features_{dim}.parquet'
    csv_path = f'{WORK_ROOT}/features/pssm_features_{dim}.csv'
    cache_path = parquet_path if os.path.exists(parquet_path) else csv_path
    feat_df, feat_cols = load_feature_cache(cache_path)
    train, test = load_anticrispr_with_ids(BENCHMARKS_DIR, benchmark_name='anticrispr_binary')
    train = attach_pssm_features(train, feat_df, feat_cols)
    test = attach_pssm_features(test, feat_df, feat_cols)
    return train, test, feat_cols

def run_baseline_config(seed: int, head_type: str, dropout_rate: float, lr: float, max_epochs_per_stage: int = 8):
    train_df, test_df, _ = FEATURE_DATA['310']
    sub_train, sub_valid = train_test_split(
        train_df[['seq','label']], test_size=0.1, stratify=train_df['label'], random_state=seed
    )
    output_type = OutputType(False, 'binary')
    output_spec = OutputSpec(output_type, [0, 1])
    pmg, enc = load_pretrained_model(
        local_model_dump_dir=f'{PROJECT_ROOT}/proteinbert_models',
        download_model_dump_if_not_exists=True,
        validate_downloading=False,
    )
    mg = FinetuningModelGenerator(
        pmg,
        output_spec=output_spec,
        pretraining_model_manipulation_function=get_model_with_hidden_layers_as_outputs,
        dropout_rate=dropout_rate,
        head_type=head_type,
        loss_type='bce',
        lr=lr,
    )
    finetune(
        mg,
        enc,
        output_spec,
        sub_train['seq'],
        sub_train['label'],
        sub_valid['seq'],
        sub_valid['label'],
        seq_len=512,
        batch_size=8,
        max_epochs_per_stage=max_epochs_per_stage,
        begin_with_frozen_pretrained_layers=True,
        n_final_epochs=0,
    )
    model = mg.create_model(512)
    X_valid = enc.encode_X(sub_valid['seq'].tolist(), 512)
    valid_prob = model.predict(X_valid, batch_size=8, verbose=0).reshape(-1)
    thr = find_best_thr(sub_valid['label'].to_numpy(), valid_prob)
    X_test = enc.encode_X(test_df['seq'].tolist(), 512)
    test_prob = model.predict(X_test, batch_size=8, verbose=0).reshape(-1)
    return evaluate_binary(test_df['label'].to_numpy(), test_prob, thr=thr)

def run_pssm_only(seed: int, dim: str, top_k: int = None):
    train_df, test_df, feat_cols = FEATURE_DATA[dim]
    sub_train, sub_valid = train_test_split(train_df, test_size=0.1, stratify=train_df['label'], random_state=seed)
    X_tr = sub_train[feat_cols].to_numpy(dtype=np.float32)
    X_va = sub_valid[feat_cols].to_numpy(dtype=np.float32)
    X_te = test_df[feat_cols].to_numpy(dtype=np.float32)
    y_tr = sub_train['label'].astype(int).to_numpy()
    y_va = sub_valid['label'].astype(int).to_numpy()
    y_te = test_df['label'].astype(int).to_numpy()
    scaler = StandardScaler()
    X_tr = scaler.fit_transform(X_tr)
    X_va = scaler.transform(X_va)
    X_te = scaler.transform(X_te)
    if top_k is not None:
        selector = SelectKBest(score_func=f_classif, k=min(top_k, X_tr.shape[1]))
        X_tr = selector.fit_transform(X_tr, y_tr)
        X_va = selector.transform(X_va)
        X_te = selector.transform(X_te)
    clf = LogisticRegression(max_iter=2000, solver='liblinear', random_state=seed)
    clf.fit(X_tr, y_tr)
    va_prob = clf.predict_proba(X_va)[:, 1]
    thr = find_best_thr(y_va, va_prob)
    te_prob = clf.predict_proba(X_te)[:, 1]
    return evaluate_binary(y_te, te_prob, thr=thr)

def run_fusion(seed: int, dim: str, cfg: FusionTrainConfig):
    train_df, test_df, feat_cols = FEATURE_DATA[dim]
    pmg, enc = load_pretrained_model(
        local_model_dump_dir=f'{PROJECT_ROOT}/proteinbert_models',
        download_model_dump_if_not_exists=True,
        validate_downloading=False,
    )
    return run_finetune_with_pssm(pmg, enc, train_df, test_df, feat_cols, seed=seed, cfg=cfg)

def summarize_by_exp(df: pd.DataFrame):
    if df.empty:
        return df
    return df.groupby('Exp')[['AUC','AUPRC','F1','MCC','Brier','ECE']].agg(['mean','std']).sort_values(('AUPRC','mean'), ascending=False)

# 载入 110/310/710/1110 四套特征（110 取 310 前 110 维）
FEATURE_DATA = {}
FEATURE_DATA['310'] = load_feature_set('310')
FEATURE_DATA['710'] = load_feature_set('710')
FEATURE_DATA['1110'] = load_feature_set('1110')
train_310, test_310, cols_310 = FEATURE_DATA['310']
FEATURE_DATA['110'] = (train_310.copy(), test_310.copy(), cols_310[:110])
print('Loaded feature dimensions:', {k: len(v[2]) for k, v in FEATURE_DATA.items()})
# Out:
# Loaded feature dimensions: {'310': 310, '710': 710, '1110': 1110, '110': 110}

# %%
# Exp 0.1 数据与样本对齐检查
for dim in ['110','310','710','1110']:
    tr, te, cols = FEATURE_DATA[dim]
    print(f'dim={dim}: train={tr.shape}, test={te.shape}, feat_dim={len(cols)}')
    print('  sample_id unique (train/test):', tr['sample_id'].nunique(), te['sample_id'].nunique())
# Out:
# dim=110: train=(1107, 313), test=(286, 313), feat_dim=110
#   sample_id unique (train/test): 1107 286
# dim=310: train=(1107, 313), test=(286, 313), feat_dim=310
#   sample_id unique (train/test): 1107 286
# dim=710: train=(1107, 713), test=(286, 713), feat_dim=710
#   sample_id unique (train/test): 1107 286
# dim=1110: train=(1107, 1113), test=(286, 1113), feat_dim=1110
#   sample_id unique (train/test): 1107 286

# %%
# Exp 0.2 评估协议检查（指标、阈值、排序主指标）
metric_cols = ['AUC','AUPRC','F1','MCC','Brier','ECE','Threshold']
print('metrics:', metric_cols)
print('selection in this plan: prioritize AUPRC mean, and inspect MCC/ECE as tie-breakers')
# Out:
# metrics: ['AUC', 'AUPRC', 'F1', 'MCC', 'Brier', 'ECE', 'Threshold']
# selection in this plan: prioritize AUPRC mean, and inspect MCC/ECE as tie-breakers

# %%
# Exp 0.3 输出结构与保存路径检查
print('result file target:', f'{WORK_ROOT}/features/full_plan_exp_results.csv')
print('summary file target:', f'{WORK_ROOT}/features/full_plan_exp_summary.csv')
print('result rows currently in memory:', len(RESULTS))
# Out:
# result file target: /home/nemophila/projects/protein_bert/pssm_work/features/full_plan_exp_results.csv
# summary file target: /home/nemophila/projects/protein_bert/pssm_work/features/full_plan_exp_summary.csv
# result rows currently in memory: 0

# %%
# Exp 1.1 Baseline_head_default
for seed in SEEDS:
    print(f'Exp1.1 seed={seed}')
    m = run_baseline_config(seed=seed, head_type='default', dropout_rate=0.4, lr=2e-5)
    record_result('Baseline_head_default', seed, m, extra={'Stage': '1', 'head_type': 'default'})
to_results_df().query("Exp == 'Baseline_head_default'")
# Out:
# Exp1.1 seed=0
# [2026_02_13-17:37:34] Training set: Filtered out 0 of 996 (0.0%) records of lengths exceeding 510.
# [2026_02_13-17:37:34] Validation set: Filtered out 0 of 111 (0.0%) records of lengths exceeding 510.
# [2026_02_13-17:37:34] Training with frozen pretrained layers...
# 2026-02-13 17:37:34.708573: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2026-02-13 17:37:34.709599: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2026-02-13 17:37:34.736944: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:2a:00.0 name: NVIDIA L40S computeCapability: 8.9
# coreClock: 2.52GHz coreCount: 142 deviceMemorySize: 44.53GiB deviceMemoryBandwidth: 804.75GiB/s
# 2026-02-13 17:37:34.737089: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 1 with properties:
# pciBusID: 0000:ab:00.0 name: NVIDIA L40S computeCapability: 8.9
# coreClock: 2.52GHz coreCount: 142 deviceMemorySize: 44.53GiB deviceMemoryBandwidth: 804.75GiB/s
# 2026-02-13 17:37:34.737110: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2026-02-13 17:37:34.739116: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2026-02-13 17:37:34.739186: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2026-02-13 17:37:34.740077: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2026-02-13 17:37:34.740316: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2026-02-13 17:37:34.742410: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2026-02-13 17:37:34.742901: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2026-02-13 17:37:34.743042: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2026-02-13 17:37:34.743602: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0, 1
# 2026-02-13 17:37:34.744316: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-02-13 17:37:34.758705: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2026-02-13 17:37:34.890457: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:2a:00.0 name: NVIDIA L40S computeCapability: 8.9
# coreClock: 2.52GHz coreCount: 142 deviceMemorySize: 44.53GiB deviceMemoryBandwidth: 804.75GiB/s
# 2026-02-13 17:37:34.890597: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 1 with properties:
# pciBusID: 0000:ab:00.0 name: NVIDIA L40S computeCapability: 8.9
# coreClock: 2.52GHz coreCount: 142 deviceMemorySize: 44.53GiB deviceMemoryBandwidth: 804.75GiB/s
# 2026-02-13 17:37:34.890624: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2026-02-13 17:37:34.890639: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2026-02-13 17:37:34.890650: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2026-02-13 17:37:34.890661: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2026-02-13 17:37:34.890672: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2026-02-13 17:37:34.890682: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2026-02-13 17:37:34.890693: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2026-02-13 17:37:34.890704: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2026-02-13 17:37:34.891116: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0, 1
# 2026-02-13 17:37:34.891144: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2026-02-13 17:37:35.671345: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2026-02-13 17:37:35.671382: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0 1
# 2026-02-13 17:37:35.671391: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N Y
# 2026-02-13 17:37:35.671395: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 1:   Y N
# 2026-02-13 17:37:35.672186: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 42297 MB memory) -> physical GPU (device: 0, name: NVIDIA L40S, pci bus id: 0000:2a:00.0, compute capability: 8.9)
# 2026-02-13 17:37:35.672982: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:1 with 42307 MB memory) -> physical GPU (device: 1, name: NVIDIA L40S, pci bus id: 0000:ab:00.0, compute capability: 8.9)
# 2026-02-13 17:37:37.442418: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2026-02-13 17:37:37.442852: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2500000000 Hz
# Epoch 1/8
# 2026-02-13 17:37:41.779609: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2026-02-13 17:37:42.240245: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2026-02-13 17:37:42.247806: I tensorflow/stream_executor/cuda/cuda_blas.cc:1838] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2026-02-13 17:37:42.248450: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2026-02-13 17:37:44.285156: W tensorflow/stream_executor/gpu/asm_compiler.cc:63] Running ptxas --version returned 256
# 2026-02-13 17:37:44.478613: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] Internal: ptxas exited with non-zero error code 256, output:
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 125/125 [==============================] - 29s 134ms/step - loss: 0.6681 - val_loss: 0.6084
# Epoch 2/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.5869 - val_loss: 0.5569
# Epoch 3/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.5571 - val_loss: 0.5245
# Epoch 4/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.5290 - val_loss: 0.5041
# Epoch 5/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.4849 - val_loss: 0.4904
# Epoch 6/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.4828 - val_loss: 0.4814
# Epoch 7/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.4610 - val_loss: 0.4747
# Epoch 8/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.4398 - val_loss: 0.4696
# [2026_02_13-17:38:27] Training the entire fine-tuned model...
# [2026_02_13-17:38:48] Incompatible number of optimizer weights - will not initialize them.
# Epoch 1/8
# 125/125 [==============================] - 32s 135ms/step - loss: 0.4505 - val_loss: 0.4572
# Epoch 2/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.4345 - val_loss: 0.4412
# Epoch 3/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.4085 - val_loss: 0.4039
# Epoch 4/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.3557 - val_loss: 0.3485
# Epoch 5/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.2919 - val_loss: 0.3494
# Epoch 6/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.2688 - val_loss: 0.3428
# Epoch 7/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.2218 - val_loss: 0.3300
# Epoch 8/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.1889 - val_loss: 0.3247
# Exp1.1 seed=11
# [2026_02_13-17:40:10] Training set: Filtered out 0 of 996 (0.0%) records of lengths exceeding 510.
# [2026_02_13-17:40:10] Validation set: Filtered out 0 of 111 (0.0%) records of lengths exceeding 510.
# [2026_02_13-17:40:10] Training with frozen pretrained layers...
# Epoch 1/8
# 125/125 [==============================] - 9s 34ms/step - loss: 0.6610 - val_loss: 0.6014
# Epoch 2/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.5873 - val_loss: 0.5493
# Epoch 3/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.5395 - val_loss: 0.5166
# Epoch 4/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.5084 - val_loss: 0.4958
# Epoch 5/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.5053 - val_loss: 0.4818
# Epoch 6/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.4828 - val_loss: 0.4715
# Epoch 7/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.4735 - val_loss: 0.4640
# Epoch 8/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.4899 - val_loss: 0.4578
# [2026_02_13-17:40:42] Training the entire fine-tuned model...
# [2026_02_13-17:40:48] Incompatible number of optimizer weights - will not initialize them.
# Epoch 1/8
# 125/125 [==============================] - 11s 57ms/step - loss: 0.4560 - val_loss: 0.4424
# Epoch 2/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.4406 - val_loss: 0.4233
# Epoch 3/8
# 125/125 [==============================] - 6s 47ms/step - loss: 0.4134 - val_loss: 0.3776
# Epoch 4/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.3467 - val_loss: 0.3131
# Epoch 5/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.2966 - val_loss: 0.2942
# Epoch 6/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.2537 - val_loss: 0.2801
# Epoch 7/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.2147 - val_loss: 0.2572
# Epoch 8/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.1654 - val_loss: 0.2568
# Exp1.1 seed=22
# [2026_02_13-17:41:43] Training set: Filtered out 0 of 996 (0.0%) records of lengths exceeding 510.
# [2026_02_13-17:41:43] Validation set: Filtered out 0 of 111 (0.0%) records of lengths exceeding 510.
# [2026_02_13-17:41:43] Training with frozen pretrained layers...
# Epoch 1/8
# 125/125 [==============================] - 9s 33ms/step - loss: 0.6775 - val_loss: 0.6147
# Epoch 2/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.6058 - val_loss: 0.5621
# Epoch 3/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.5515 - val_loss: 0.5294
# Epoch 4/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.5097 - val_loss: 0.5095
# Epoch 5/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.4770 - val_loss: 0.4959
# Epoch 6/8
# 125/125 [==============================] - 3s 23ms/step - loss: 0.4884 - val_loss: 0.4864
# Epoch 7/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.4633 - val_loss: 0.4795
# Epoch 8/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.4430 - val_loss: 0.4740
# [2026_02_13-17:42:13] Training the entire fine-tuned model...
# [2026_02_13-17:42:19] Incompatible number of optimizer weights - will not initialize them.
# Epoch 1/8
# 125/125 [==============================] - 11s 56ms/step - loss: 0.4530 - val_loss: 0.4556
# Epoch 2/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.4297 - val_loss: 0.4205
# Epoch 3/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.3738 - val_loss: 0.3452
# Epoch 4/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.2918 - val_loss: 0.3587
# Epoch 5/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.2522 - val_loss: 0.3031
# Epoch 6/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.2139 - val_loss: 0.3222
# Epoch 7/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.1795 - val_loss: 0.3467
# Epoch 8/8
# 125/125 [==============================] - 6s 45ms/step - loss: 0.1414 - val_loss: 0.3665
# Exp1.1 seed=33
# [2026_02_13-17:43:13] Training set: Filtered out 0 of 996 (0.0%) records of lengths exceeding 510.
# [2026_02_13-17:43:14] Validation set: Filtered out 0 of 111 (0.0%) records of lengths exceeding 510.
# [2026_02_13-17:43:14] Training with frozen pretrained layers...
# Epoch 1/8
# 125/125 [==============================] - 9s 34ms/step - loss: 0.6477 - val_loss: 0.5881
# Epoch 2/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.5735 - val_loss: 0.5430
# Epoch 3/8
# 125/125 [==============================] - 3s 23ms/step - loss: 0.5335 - val_loss: 0.5158
# Epoch 4/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.4991 - val_loss: 0.4975
# Epoch 5/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.4889 - val_loss: 0.4859
# Epoch 6/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.4861 - val_loss: 0.4775
# Epoch 7/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.4641 - val_loss: 0.4711
# Epoch 8/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.4404 - val_loss: 0.4660
# [2026_02_13-17:43:44] Training the entire fine-tuned model...
# [2026_02_13-17:43:50] Incompatible number of optimizer weights - will not initialize them.
# Epoch 1/8
# 125/125 [==============================] - 11s 55ms/step - loss: 0.4548 - val_loss: 0.4525
# Epoch 2/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.4336 - val_loss: 0.4318
# Epoch 3/8
# 125/125 [==============================] - 6s 45ms/step - loss: 0.3830 - val_loss: 0.3991
# Epoch 4/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.3454 - val_loss: 0.3693
# Epoch 5/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.2795 - val_loss: 0.3988
# Epoch 6/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.2619 - val_loss: 0.3784
# Epoch 7/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.2276 - val_loss: 0.3981
# Epoch 8/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.1980 - val_loss: 0.3995
# Exp1.1 seed=44
# [2026_02_13-17:44:44] Training set: Filtered out 0 of 996 (0.0%) records of lengths exceeding 510.
# [2026_02_13-17:44:44] Validation set: Filtered out 0 of 111 (0.0%) records of lengths exceeding 510.
# [2026_02_13-17:44:44] Training with frozen pretrained layers...
# Epoch 1/8
# 125/125 [==============================] - 9s 34ms/step - loss: 0.6688 - val_loss: 0.6075
# Epoch 2/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.5864 - val_loss: 0.5552
# Epoch 3/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.5390 - val_loss: 0.5233
# Epoch 4/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.5273 - val_loss: 0.5021
# Epoch 5/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.4869 - val_loss: 0.4883
# Epoch 6/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.4806 - val_loss: 0.4786
# Epoch 7/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.4671 - val_loss: 0.4714
# Epoch 8/8
# 125/125 [==============================] - 3s 23ms/step - loss: 0.4606 - val_loss: 0.4657
# [2026_02_13-17:45:15] Training the entire fine-tuned model...
# [2026_02_13-17:45:21] Incompatible number of optimizer weights - will not initialize them.
# Epoch 1/8
# 125/125 [==============================] - 11s 55ms/step - loss: 0.4564 - val_loss: 0.4512
# Epoch 2/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.4376 - val_loss: 0.4287
# Epoch 3/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.4066 - val_loss: 0.3693
# Epoch 4/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.3518 - val_loss: 0.3465
# Epoch 5/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.2965 - val_loss: 0.3260
# Epoch 6/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.2663 - val_loss: 0.3127
# Epoch 7/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.2162 - val_loss: 0.3055
# Epoch 8/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.1983 - val_loss: 0.3019
#                      Exp  Seed       AUC     AUPRC        F1       MCC  \
# 0  Baseline_head_default     0  0.812870  0.526331  0.433333  0.372380
# 1  Baseline_head_default    11  0.783432  0.448844  0.389610  0.329296
# 2  Baseline_head_default    22  0.786095  0.447901  0.357143  0.294240
# 3  Baseline_head_default    33  0.813166  0.459750  0.400000  0.342959
# 4  Baseline_head_default    44  0.802071  0.415521  0.361111  0.291936
#
#       Brier       ECE  Threshold Stage head_type
# 0  0.072586  0.060235        0.4     1   default
# 1  0.085973  0.075089        0.3     1   default
# 2  0.077597  0.066423        0.2     1   default
# 3  0.083882  0.074316        0.6     1   default
# 4  0.073604  0.045049        0.3     1   default

# %%
# Exp 1.2 Baseline_head_two_layer
for seed in SEEDS:
    print(f'Exp1.2 seed={seed}')
    m = run_baseline_config(seed=seed, head_type='two_layer', dropout_rate=0.4, lr=2e-5)
    record_result('Baseline_head_two_layer', seed, m, extra={'Stage': '1', 'head_type': 'two_layer'})
to_results_df().query("Exp == 'Baseline_head_two_layer'")
# Out:
# Exp1.2 seed=0
# [2026_02_13-17:46:16] Training set: Filtered out 0 of 996 (0.0%) records of lengths exceeding 510.
# [2026_02_13-17:46:16] Validation set: Filtered out 0 of 111 (0.0%) records of lengths exceeding 510.
# [2026_02_13-17:46:16] Training with frozen pretrained layers...
# Epoch 1/8
# 125/125 [==============================] - 9s 34ms/step - loss: 0.6655 - val_loss: 0.3905
# Epoch 2/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.3938 - val_loss: 0.3686
# Epoch 3/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.4087 - val_loss: 0.3619
# Epoch 4/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.3291 - val_loss: 0.3615
# Epoch 5/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.3285 - val_loss: 0.3383
# Epoch 6/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.3137 - val_loss: 0.3384
# Epoch 7/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.2842 - val_loss: 0.3579
# Epoch 8/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.2655 - val_loss: 0.3570
# [2026_02_13-17:46:47] Training the entire fine-tuned model...
# [2026_02_13-17:46:53] Incompatible number of optimizer weights - will not initialize them.
# Epoch 1/8
# 125/125 [==============================] - 11s 56ms/step - loss: 0.2630 - val_loss: 0.3504
# Epoch 2/8
# 125/125 [==============================] - 6s 47ms/step - loss: 0.2452 - val_loss: 0.3417
# Epoch 3/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.2027 - val_loss: 0.3966
# Epoch 4/8
# 125/125 [==============================] - 6s 47ms/step - loss: 0.1938 - val_loss: 0.3740
# Epoch 5/8
# 125/125 [==============================] - 6s 47ms/step - loss: 0.1789 - val_loss: 0.3552
# Epoch 6/8
# 125/125 [==============================] - 6s 47ms/step - loss: 0.1478 - val_loss: 0.3784
# Epoch 7/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.1355 - val_loss: 0.3668
# Epoch 8/8
# 125/125 [==============================] - 6s 47ms/step - loss: 0.1177 - val_loss: 0.4240
# Exp1.2 seed=11
# [2026_02_13-17:47:48] Training set: Filtered out 0 of 996 (0.0%) records of lengths exceeding 510.
# [2026_02_13-17:47:48] Validation set: Filtered out 0 of 111 (0.0%) records of lengths exceeding 510.
# [2026_02_13-17:47:48] Training with frozen pretrained layers...
# Epoch 1/8
# 125/125 [==============================] - 9s 35ms/step - loss: 0.5773 - val_loss: 0.3169
# Epoch 2/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.3923 - val_loss: 0.2958
# Epoch 3/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.3548 - val_loss: 0.2737
# Epoch 4/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.3320 - val_loss: 0.2741
# Epoch 5/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.3061 - val_loss: 0.2620
# Epoch 6/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.3001 - val_loss: 0.2606
# Epoch 7/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.2544 - val_loss: 0.2454
# Epoch 8/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.2835 - val_loss: 0.2457
# [2026_02_13-17:48:20] Training the entire fine-tuned model...
# [2026_02_13-17:48:27] Incompatible number of optimizer weights - will not initialize them.
# Epoch 1/8
# 125/125 [==============================] - 12s 58ms/step - loss: 0.2746 - val_loss: 0.2533
# Epoch 2/8
# 125/125 [==============================] - 6s 47ms/step - loss: 0.2429 - val_loss: 0.2335
# Epoch 3/8
# 125/125 [==============================] - 6s 47ms/step - loss: 0.2124 - val_loss: 0.2579
# Epoch 4/8
# 125/125 [==============================] - 6s 47ms/step - loss: 0.1994 - val_loss: 0.2479
# Epoch 5/8
# 125/125 [==============================] - 6s 47ms/step - loss: 0.1774 - val_loss: 0.2340
# Epoch 6/8
# 125/125 [==============================] - 6s 47ms/step - loss: 0.1476 - val_loss: 0.2443
# Epoch 7/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.1217 - val_loss: 0.2507
# Epoch 8/8
# 125/125 [==============================] - 6s 47ms/step - loss: 0.1239 - val_loss: 0.2450
# Exp1.2 seed=22
# [2026_02_13-17:49:24] Training set: Filtered out 0 of 996 (0.0%) records of lengths exceeding 510.
# [2026_02_13-17:49:24] Validation set: Filtered out 0 of 111 (0.0%) records of lengths exceeding 510.
# [2026_02_13-17:49:24] Training with frozen pretrained layers...
# Epoch 1/8
# 125/125 [==============================] - 10s 34ms/step - loss: 0.5805 - val_loss: 0.3331
# Epoch 2/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.3655 - val_loss: 0.3627
# Epoch 3/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.4036 - val_loss: 0.2878
# Epoch 4/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.3637 - val_loss: 0.2851
# Epoch 5/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.3444 - val_loss: 0.2891
# Epoch 6/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.2917 - val_loss: 0.2714
# Epoch 7/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.2769 - val_loss: 0.2690
# Epoch 8/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.2696 - val_loss: 0.2675
# [2026_02_13-17:49:56] Training the entire fine-tuned model...
# [2026_02_13-17:50:02] Incompatible number of optimizer weights - will not initialize them.
# Epoch 1/8
# 125/125 [==============================] - 11s 57ms/step - loss: 0.2657 - val_loss: 0.2716
# Epoch 2/8
# 125/125 [==============================] - 6s 47ms/step - loss: 0.2449 - val_loss: 0.2604
# Epoch 3/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.2313 - val_loss: 0.2649
# Epoch 4/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.2162 - val_loss: 0.2650
# Epoch 5/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.1758 - val_loss: 0.2858
# Epoch 6/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.1710 - val_loss: 0.2960
# Epoch 7/8
# 125/125 [==============================] - 6s 47ms/step - loss: 0.1408 - val_loss: 0.2674
# Epoch 8/8
# 125/125 [==============================] - 6s 47ms/step - loss: 0.1179 - val_loss: 0.2974
# Exp1.2 seed=33
# [2026_02_13-17:50:57] Training set: Filtered out 0 of 996 (0.0%) records of lengths exceeding 510.
# [2026_02_13-17:50:57] Validation set: Filtered out 0 of 111 (0.0%) records of lengths exceeding 510.
# [2026_02_13-17:50:57] Training with frozen pretrained layers...
# Epoch 1/8
# 125/125 [==============================] - 9s 35ms/step - loss: 0.5033 - val_loss: 0.3629
# Epoch 2/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.3897 - val_loss: 0.3950
# Epoch 3/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.3931 - val_loss: 0.3890
# Epoch 4/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.3300 - val_loss: 0.3898
# Epoch 5/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.3223 - val_loss: 0.3716
# Epoch 6/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.2897 - val_loss: 0.3884
# Epoch 7/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.2847 - val_loss: 0.3922
# Epoch 8/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.2737 - val_loss: 0.4072
# [2026_02_13-17:51:29] Training the entire fine-tuned model...
# [2026_02_13-17:51:35] Incompatible number of optimizer weights - will not initialize them.
# Epoch 1/8
# 125/125 [==============================] - 11s 56ms/step - loss: 0.2470 - val_loss: 0.4001
# Epoch 2/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.2279 - val_loss: 0.3987
# Epoch 3/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.1919 - val_loss: 0.4132
# Epoch 4/8
# 125/125 [==============================] - 6s 47ms/step - loss: 0.1617 - val_loss: 0.4597
# Epoch 5/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.1707 - val_loss: 0.4514
# Epoch 6/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.1492 - val_loss: 0.4393
# Epoch 7/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.1361 - val_loss: 0.4693
# Epoch 8/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.1087 - val_loss: 0.4642
# Exp1.2 seed=44
# [2026_02_13-17:52:30] Training set: Filtered out 0 of 996 (0.0%) records of lengths exceeding 510.
# [2026_02_13-17:52:30] Validation set: Filtered out 0 of 111 (0.0%) records of lengths exceeding 510.
# [2026_02_13-17:52:30] Training with frozen pretrained layers...
# Epoch 1/8
# 125/125 [==============================] - 9s 35ms/step - loss: 0.7600 - val_loss: 0.3890
# Epoch 2/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.4474 - val_loss: 0.4013
# Epoch 3/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.3798 - val_loss: 0.3849
# Epoch 4/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.3559 - val_loss: 0.3674
# Epoch 5/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.3383 - val_loss: 0.3667
# Epoch 6/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.2891 - val_loss: 0.3595
# Epoch 7/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.2884 - val_loss: 0.3716
# Epoch 8/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.2783 - val_loss: 0.3601
# [2026_02_13-17:53:01] Training the entire fine-tuned model...
# [2026_02_13-17:53:07] Incompatible number of optimizer weights - will not initialize them.
# Epoch 1/8
# 125/125 [==============================] - 11s 56ms/step - loss: 0.2775 - val_loss: 0.3771
# Epoch 2/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.2484 - val_loss: 0.3446
# Epoch 3/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.2192 - val_loss: 0.3571
# Epoch 4/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.2078 - val_loss: 0.3705
# Epoch 5/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.1862 - val_loss: 0.3589
# Epoch 6/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.1617 - val_loss: 0.3944
# Epoch 7/8
# 125/125 [==============================] - 6s 45ms/step - loss: 0.1526 - val_loss: 0.3810
# Epoch 8/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.1302 - val_loss: 0.3915
#                        Exp  Seed       AUC     AUPRC        F1       MCC  \
# 1  Baseline_head_two_layer     0  0.897929  0.637807  0.535714  0.487139
# 3  Baseline_head_two_layer    11  0.902811  0.609123  0.528302  0.480255
# 5  Baseline_head_two_layer    22  0.878107  0.544454  0.433333  0.372380
# 7  Baseline_head_two_layer    33  0.881213  0.609083  0.396396  0.379833
# 9  Baseline_head_two_layer    44  0.884467  0.554960  0.384615  0.323077
#
#       Brier       ECE  Threshold Stage  head_type
# 1  0.052474  0.040079       0.25     1  two_layer
# 3  0.060129  0.060666       0.40     1  two_layer
# 5  0.065439  0.051847       0.30     1  two_layer
# 7  0.073061  0.068348       0.10     1  two_layer
# 9  0.073809  0.063993       0.55     1  two_layer

# %%
# Exp 1.3 Baseline_head_two_layer_lowdrop (dropout_rate=0.3)
for seed in SEEDS:
    print(f'Exp1.3 seed={seed}')
    m = run_baseline_config(seed=seed, head_type='two_layer', dropout_rate=0.3, lr=2e-5)
    record_result('Baseline_head_two_layer_lowdrop', seed, m, extra={'Stage': '1', 'head_type': 'two_layer'})
to_results_df().query("Exp == 'Baseline_head_two_layer_lowdrop'")
# Out:
# Exp1.3 seed=0
# [2026_02_13-17:54:02] Training set: Filtered out 0 of 996 (0.0%) records of lengths exceeding 510.
# [2026_02_13-17:54:02] Validation set: Filtered out 0 of 111 (0.0%) records of lengths exceeding 510.
# [2026_02_13-17:54:02] Training with frozen pretrained layers...
# Epoch 1/8
# 125/125 [==============================] - 9s 34ms/step - loss: 0.5307 - val_loss: 0.3818
# Epoch 2/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.4040 - val_loss: 0.3629
# Epoch 3/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.3260 - val_loss: 0.3662
# Epoch 4/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.3150 - val_loss: 0.3724
# Epoch 5/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.2792 - val_loss: 0.3319
# Epoch 6/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.2815 - val_loss: 0.3413
# Epoch 7/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.2567 - val_loss: 0.3534
# Epoch 8/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.2303 - val_loss: 0.3491
# [2026_02_13-17:54:33] Training the entire fine-tuned model...
# [2026_02_13-17:54:39] Incompatible number of optimizer weights - will not initialize them.
# Epoch 1/8
# 125/125 [==============================] - 11s 56ms/step - loss: 0.2487 - val_loss: 0.3367
# Epoch 2/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.2070 - val_loss: 0.3433
# Epoch 3/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.1872 - val_loss: 0.3598
# Epoch 4/8
# 125/125 [==============================] - 6s 45ms/step - loss: 0.1587 - val_loss: 0.3779
# Epoch 5/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.1398 - val_loss: 0.3656
# Epoch 6/8
# 125/125 [==============================] - 6s 47ms/step - loss: 0.1160 - val_loss: 0.4034
# Epoch 7/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.1020 - val_loss: 0.4042
# Epoch 8/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.0784 - val_loss: 0.4062
# Exp1.3 seed=11
# [2026_02_13-17:55:33] Training set: Filtered out 0 of 996 (0.0%) records of lengths exceeding 510.
# [2026_02_13-17:55:34] Validation set: Filtered out 0 of 111 (0.0%) records of lengths exceeding 510.
# [2026_02_13-17:55:34] Training with frozen pretrained layers...
# Epoch 1/8
# 125/125 [==============================] - 9s 34ms/step - loss: 0.5957 - val_loss: 0.3541
# Epoch 2/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.4170 - val_loss: 0.3083
# Epoch 3/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.3690 - val_loss: 0.2759
# Epoch 4/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.3603 - val_loss: 0.2809
# Epoch 5/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.3008 - val_loss: 0.2550
# Epoch 6/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.3126 - val_loss: 0.2508
# Epoch 7/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.2467 - val_loss: 0.2483
# Epoch 8/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.2906 - val_loss: 0.2385
# [2026_02_13-17:56:05] Training the entire fine-tuned model...
# [2026_02_13-17:56:11] Incompatible number of optimizer weights - will not initialize them.
# Epoch 1/8
# 125/125 [==============================] - 11s 56ms/step - loss: 0.2398 - val_loss: 0.2399
# Epoch 2/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.2115 - val_loss: 0.2110
# Epoch 3/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.1837 - val_loss: 0.2168
# Epoch 4/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.1698 - val_loss: 0.2161
# Epoch 5/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.1381 - val_loss: 0.2434
# Epoch 6/8
# 125/125 [==============================] - 6s 47ms/step - loss: 0.1214 - val_loss: 0.2204
# Epoch 7/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.1080 - val_loss: 0.2366
# Epoch 8/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.0981 - val_loss: 0.2417
# Exp1.3 seed=22
# [2026_02_13-17:57:05] Training set: Filtered out 0 of 996 (0.0%) records of lengths exceeding 510.
# [2026_02_13-17:57:05] Validation set: Filtered out 0 of 111 (0.0%) records of lengths exceeding 510.
# [2026_02_13-17:57:05] Training with frozen pretrained layers...
# Epoch 1/8
# 125/125 [==============================] - 9s 34ms/step - loss: 0.6497 - val_loss: 0.3578
# Epoch 2/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.4556 - val_loss: 0.3385
# Epoch 3/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.3673 - val_loss: 0.3157
# Epoch 4/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.3333 - val_loss: 0.3039
# Epoch 5/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.3172 - val_loss: 0.3116
# Epoch 6/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.2722 - val_loss: 0.2835
# Epoch 7/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.2974 - val_loss: 0.2979
# Epoch 8/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.2585 - val_loss: 0.2892
# [2026_02_13-17:57:37] Training the entire fine-tuned model...
# [2026_02_13-17:57:43] Incompatible number of optimizer weights - will not initialize them.
# Epoch 1/8
# 125/125 [==============================] - 11s 56ms/step - loss: 0.2397 - val_loss: 0.2744
# Epoch 2/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.2127 - val_loss: 0.2937
# Epoch 3/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.1954 - val_loss: 0.2946
# Epoch 4/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.1676 - val_loss: 0.2792
# Epoch 5/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.1482 - val_loss: 0.3091
# Epoch 6/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.1257 - val_loss: 0.3738
# Epoch 7/8
# 125/125 [==============================] - 6s 47ms/step - loss: 0.0959 - val_loss: 0.2969
# Epoch 8/8
# 125/125 [==============================] - 6s 47ms/step - loss: 0.0713 - val_loss: 0.3467
# Exp1.3 seed=33
# [2026_02_13-17:58:37] Training set: Filtered out 0 of 996 (0.0%) records of lengths exceeding 510.
# [2026_02_13-17:58:38] Validation set: Filtered out 0 of 111 (0.0%) records of lengths exceeding 510.
# [2026_02_13-17:58:38] Training with frozen pretrained layers...
# Epoch 1/8
# 125/125 [==============================] - 9s 34ms/step - loss: 0.7098 - val_loss: 0.4006
# Epoch 2/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.3866 - val_loss: 0.3693
# Epoch 3/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.3181 - val_loss: 0.3657
# Epoch 4/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.2898 - val_loss: 0.4001
# Epoch 5/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.2800 - val_loss: 0.4077
# Epoch 6/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.2882 - val_loss: 0.3945
# Epoch 7/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.2294 - val_loss: 0.3745
# Epoch 8/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.2336 - val_loss: 0.3675
# [2026_02_13-17:59:09] Training the entire fine-tuned model...
# [2026_02_13-17:59:15] Incompatible number of optimizer weights - will not initialize them.
# Epoch 1/8
# 125/125 [==============================] - 11s 57ms/step - loss: 0.2386 - val_loss: 0.3953
# Epoch 2/8
# 125/125 [==============================] - 6s 47ms/step - loss: 0.2116 - val_loss: 0.4193
# Epoch 3/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.1857 - val_loss: 0.4407
# Epoch 4/8
# 125/125 [==============================] - 6s 47ms/step - loss: 0.1706 - val_loss: 0.4240
# Epoch 5/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.1318 - val_loss: 0.4531
# Epoch 6/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.1266 - val_loss: 0.4873
# Epoch 7/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.1054 - val_loss: 0.4986
# Epoch 8/8
# 125/125 [==============================] - 6s 47ms/step - loss: 0.0891 - val_loss: 0.5186
# Exp1.3 seed=44
# [2026_02_13-18:00:10] Training set: Filtered out 0 of 996 (0.0%) records of lengths exceeding 510.
# [2026_02_13-18:00:11] Validation set: Filtered out 0 of 111 (0.0%) records of lengths exceeding 510.
# [2026_02_13-18:00:11] Training with frozen pretrained layers...
# Epoch 1/8
# 125/125 [==============================] - 9s 34ms/step - loss: 0.6409 - val_loss: 0.4452
# Epoch 2/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.3900 - val_loss: 0.3767
# Epoch 3/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.3039 - val_loss: 0.3674
# Epoch 4/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.3035 - val_loss: 0.3660
# Epoch 5/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.3127 - val_loss: 0.3591
# Epoch 6/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.3132 - val_loss: 0.3453
# Epoch 7/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.2604 - val_loss: 0.3507
# Epoch 8/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.2385 - val_loss: 0.3460
# [2026_02_13-18:00:42] Training the entire fine-tuned model...
# [2026_02_13-18:00:48] Incompatible number of optimizer weights - will not initialize them.
# Epoch 1/8
# 125/125 [==============================] - 11s 56ms/step - loss: 0.2426 - val_loss: 0.3486
# Epoch 2/8
# 125/125 [==============================] - 6s 45ms/step - loss: 0.2278 - val_loss: 0.3509
# Epoch 3/8
# 125/125 [==============================] - 6s 47ms/step - loss: 0.1839 - val_loss: 0.3760
# Epoch 4/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.1738 - val_loss: 0.3950
# Epoch 5/8
# 125/125 [==============================] - 6s 45ms/step - loss: 0.1389 - val_loss: 0.3772
# Epoch 6/8
# 125/125 [==============================] - 6s 45ms/step - loss: 0.1291 - val_loss: 0.4117
# Epoch 7/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.1169 - val_loss: 0.3787
# Epoch 8/8
# 125/125 [==============================] - 6s 47ms/step - loss: 0.0898 - val_loss: 0.3939
#                                 Exp  Seed       AUC     AUPRC        F1  \
# 2   Baseline_head_two_layer_lowdrop     0  0.890089  0.599235  0.447761
# 5   Baseline_head_two_layer_lowdrop    11  0.893195  0.591658  0.512821
# 8   Baseline_head_two_layer_lowdrop    22  0.875888  0.576209  0.487805
# 11  Baseline_head_two_layer_lowdrop    33  0.844970  0.567736  0.371134
# 14  Baseline_head_two_layer_lowdrop    44  0.888757  0.596883  0.529412
#
#          MCC     Brier       ECE  Threshold Stage  head_type
# 2   0.391243  0.070092  0.055788       0.35     1  two_layer
# 5   0.514895  0.076383  0.068628       0.80     1  two_layer
# 8   0.456968  0.062837  0.041439       0.10     1  two_layer
# 11  0.325054  0.063489  0.048359       0.05     1  two_layer
# 14  0.487310  0.062511  0.049631       0.30     1  two_layer

# %%
# Exp 1.4 Baseline_head_two_layer_lowlr (lr=1e-5)
for seed in SEEDS:
    print(f'Exp1.4 seed={seed}')
    m = run_baseline_config(seed=seed, head_type='two_layer', dropout_rate=0.4, lr=1e-5)
    record_result('Baseline_head_two_layer_lowlr', seed, m, extra={'Stage': '1', 'head_type': 'two_layer'})
to_results_df().query("Exp == 'Baseline_head_two_layer_lowlr'")
# Out:
# Exp1.4 seed=0
# [2026_02_13-18:01:43] Training set: Filtered out 0 of 996 (0.0%) records of lengths exceeding 510.
# [2026_02_13-18:01:43] Validation set: Filtered out 0 of 111 (0.0%) records of lengths exceeding 510.
# [2026_02_13-18:01:43] Training with frozen pretrained layers...
# Epoch 1/8
# 125/125 [==============================] - 9s 35ms/step - loss: 0.6349 - val_loss: 0.4777
# Epoch 2/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.5194 - val_loss: 0.3870
# Epoch 3/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.4257 - val_loss: 0.3672
# Epoch 4/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.3594 - val_loss: 0.3551
# Epoch 5/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.3783 - val_loss: 0.3438
# Epoch 6/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.3098 - val_loss: 0.3425
# Epoch 7/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.3482 - val_loss: 0.3360
# Epoch 8/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.3071 - val_loss: 0.3298
# [2026_02_13-18:02:15] Training the entire fine-tuned model...
# [2026_02_13-18:02:21] Incompatible number of optimizer weights - will not initialize them.
# Epoch 1/8
# 125/125 [==============================] - 11s 56ms/step - loss: 0.3126 - val_loss: 0.3325
# Epoch 2/8
# 125/125 [==============================] - 6s 47ms/step - loss: 0.2975 - val_loss: 0.3248
# Epoch 3/8
# 125/125 [==============================] - 6s 47ms/step - loss: 0.2823 - val_loss: 0.3215
# Epoch 4/8
# 125/125 [==============================] - 6s 47ms/step - loss: 0.2740 - val_loss: 0.3329
# Epoch 5/8
# 125/125 [==============================] - 6s 47ms/step - loss: 0.2510 - val_loss: 0.3192
# Epoch 6/8
# 125/125 [==============================] - 6s 47ms/step - loss: 0.2468 - val_loss: 0.3194
# Epoch 7/8
# 125/125 [==============================] - 6s 47ms/step - loss: 0.2339 - val_loss: 0.3290
# Epoch 8/8
# 125/125 [==============================] - 6s 47ms/step - loss: 0.2212 - val_loss: 0.3352
# Exp1.4 seed=11
# [2026_02_13-18:03:17] Training set: Filtered out 0 of 996 (0.0%) records of lengths exceeding 510.
# [2026_02_13-18:03:17] Validation set: Filtered out 0 of 111 (0.0%) records of lengths exceeding 510.
# [2026_02_13-18:03:17] Training with frozen pretrained layers...
# Epoch 1/8
# 125/125 [==============================] - 9s 35ms/step - loss: 0.8386 - val_loss: 0.4713
# Epoch 2/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.5060 - val_loss: 0.4197
# Epoch 3/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.4677 - val_loss: 0.3738
# Epoch 4/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.3826 - val_loss: 0.3338
# Epoch 5/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.3508 - val_loss: 0.3285
# Epoch 6/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.3460 - val_loss: 0.3336
# Epoch 7/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.3518 - val_loss: 0.3168
# Epoch 8/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.3430 - val_loss: 0.3064
# [2026_02_13-18:03:49] Training the entire fine-tuned model...
# [2026_02_13-18:03:54] Incompatible number of optimizer weights - will not initialize them.
# Epoch 1/8
# 125/125 [==============================] - 11s 56ms/step - loss: 0.3282 - val_loss: 0.3021
# Epoch 2/8
# 125/125 [==============================] - 6s 47ms/step - loss: 0.3231 - val_loss: 0.2919
# Epoch 3/8
# 125/125 [==============================] - 6s 47ms/step - loss: 0.2872 - val_loss: 0.3021
# Epoch 4/8
# 125/125 [==============================] - 6s 47ms/step - loss: 0.2615 - val_loss: 0.2753
# Epoch 5/8
# 125/125 [==============================] - 6s 47ms/step - loss: 0.2642 - val_loss: 0.2663
# Epoch 6/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.2467 - val_loss: 0.2654
# Epoch 7/8
# 125/125 [==============================] - 6s 47ms/step - loss: 0.2356 - val_loss: 0.2854
# Epoch 8/8
# 125/125 [==============================] - 6s 47ms/step - loss: 0.2229 - val_loss: 0.2619
# Exp1.4 seed=22
# [2026_02_13-18:04:50] Training set: Filtered out 0 of 996 (0.0%) records of lengths exceeding 510.
# [2026_02_13-18:04:50] Validation set: Filtered out 0 of 111 (0.0%) records of lengths exceeding 510.
# [2026_02_13-18:04:50] Training with frozen pretrained layers...
# Epoch 1/8
# 125/125 [==============================] - 9s 35ms/step - loss: 0.7245 - val_loss: 0.4819
# Epoch 2/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.4699 - val_loss: 0.3667
# Epoch 3/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.4512 - val_loss: 0.3323
# Epoch 4/8
# 125/125 [==============================] - 3s 26ms/step - loss: 0.4127 - val_loss: 0.3244
# Epoch 5/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.3610 - val_loss: 0.2976
# Epoch 6/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.3418 - val_loss: 0.3052
# Epoch 7/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.3279 - val_loss: 0.2837
# Epoch 8/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.3157 - val_loss: 0.2828
# [2026_02_13-18:05:22] Training the entire fine-tuned model...
# [2026_02_13-18:05:28] Incompatible number of optimizer weights - will not initialize them.
# Epoch 1/8
# 125/125 [==============================] - 11s 57ms/step - loss: 0.3217 - val_loss: 0.3022
# Epoch 2/8
# 125/125 [==============================] - 6s 47ms/step - loss: 0.3040 - val_loss: 0.2717
# Epoch 3/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.2714 - val_loss: 0.2749
# Epoch 4/8
# 125/125 [==============================] - 6s 47ms/step - loss: 0.2861 - val_loss: 0.2697
# Epoch 5/8
# 125/125 [==============================] - 6s 47ms/step - loss: 0.2728 - val_loss: 0.2696
# Epoch 6/8
# 125/125 [==============================] - 6s 47ms/step - loss: 0.2507 - val_loss: 0.2678
# Epoch 7/8
# 125/125 [==============================] - 6s 47ms/step - loss: 0.2505 - val_loss: 0.2613
# Epoch 8/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.2318 - val_loss: 0.2710
# Exp1.4 seed=33
# [2026_02_13-18:06:23] Training set: Filtered out 0 of 996 (0.0%) records of lengths exceeding 510.
# [2026_02_13-18:06:23] Validation set: Filtered out 0 of 111 (0.0%) records of lengths exceeding 510.
# [2026_02_13-18:06:23] Training with frozen pretrained layers...
# Epoch 1/8
# 125/125 [==============================] - 10s 36ms/step - loss: 0.5085 - val_loss: 0.4469
# Epoch 2/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.4418 - val_loss: 0.4286
# Epoch 3/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.4114 - val_loss: 0.4018
# Epoch 4/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.3933 - val_loss: 0.4062
# Epoch 5/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.3711 - val_loss: 0.4052
# Epoch 6/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.3460 - val_loss: 0.4089
# Epoch 7/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.3271 - val_loss: 0.3827
# Epoch 8/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.3022 - val_loss: 0.4052
# [2026_02_13-18:06:56] Training the entire fine-tuned model...
# [2026_02_13-18:07:01] Incompatible number of optimizer weights - will not initialize them.
# Epoch 1/8
# 125/125 [==============================] - 11s 56ms/step - loss: 0.3077 - val_loss: 0.3746
# Epoch 2/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.2806 - val_loss: 0.3994
# Epoch 3/8
# 125/125 [==============================] - 6s 47ms/step - loss: 0.2703 - val_loss: 0.3861
# Epoch 4/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.2432 - val_loss: 0.4379
# Epoch 5/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.2536 - val_loss: 0.3911
# Epoch 6/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.2295 - val_loss: 0.4296
# Epoch 7/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.2057 - val_loss: 0.4159
# Epoch 8/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.2046 - val_loss: 0.4397
# Exp1.4 seed=44
# [2026_02_13-18:07:56] Training set: Filtered out 0 of 996 (0.0%) records of lengths exceeding 510.
# [2026_02_13-18:07:56] Validation set: Filtered out 0 of 111 (0.0%) records of lengths exceeding 510.
# [2026_02_13-18:07:56] Training with frozen pretrained layers...
# Epoch 1/8
# 125/125 [==============================] - 9s 35ms/step - loss: 0.5506 - val_loss: 0.4252
# Epoch 2/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.4517 - val_loss: 0.3992
# Epoch 3/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.4161 - val_loss: 0.3848
# Epoch 4/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.3952 - val_loss: 0.3883
# Epoch 5/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.3323 - val_loss: 0.3596
# Epoch 6/8
# 125/125 [==============================] - 3s 24ms/step - loss: 0.3398 - val_loss: 0.3670
# Epoch 7/8
# 125/125 [==============================] - 3s 25ms/step - loss: 0.3428 - val_loss: 0.3497
# Epoch 8/8
# 125/125 [==============================] - 3s 23ms/step - loss: 0.3348 - val_loss: 0.3448
# [2026_02_13-18:08:27] Training the entire fine-tuned model...
# [2026_02_13-18:08:33] Incompatible number of optimizer weights - will not initialize them.
# Epoch 1/8
# 125/125 [==============================] - 11s 57ms/step - loss: 0.2986 - val_loss: 0.3481
# Epoch 2/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.2959 - val_loss: 0.3418
# Epoch 3/8
# 125/125 [==============================] - 6s 45ms/step - loss: 0.2638 - val_loss: 0.3425
# Epoch 4/8
# 125/125 [==============================] - 6s 47ms/step - loss: 0.2776 - val_loss: 0.3403
# Epoch 5/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.2414 - val_loss: 0.3387
# Epoch 6/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.2314 - val_loss: 0.3312
# Epoch 7/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.2095 - val_loss: 0.3423
# Epoch 8/8
# 125/125 [==============================] - 6s 46ms/step - loss: 0.1969 - val_loss: 0.3452
#                               Exp  Seed       AUC     AUPRC        F1  \
# 3   Baseline_head_two_layer_lowlr     0  0.877219  0.582587  0.472222
# 7   Baseline_head_two_layer_lowlr    11  0.890385  0.629714  0.438356
# 11  Baseline_head_two_layer_lowlr    22  0.864941  0.571824  0.414634
# 15  Baseline_head_two_layer_lowlr    33  0.861095  0.555948  0.430380
# 19  Baseline_head_two_layer_lowlr    44  0.886686  0.590600  0.451613
#
#          MCC     Brier       ECE  Threshold Stage  head_type
# 3   0.424360  0.056973  0.027393       0.20     1  two_layer
# 7   0.384895  0.059524  0.046954       0.30     1  two_layer
# 11  0.365017  0.059419  0.040285       0.20     1  two_layer
# 15  0.381319  0.084513  0.081865       0.35     1  two_layer
# 19  0.393333  0.060585  0.047149       0.30     1  two_layer

# %%
# Stage 1 汇总并选最佳个体 A / 次优个体 B（用于后续 Stage 2/4）
stage1_df = to_results_df().query("Stage == '1'").copy()
stage1_summary = summarize_by_exp(stage1_df)
display(stage1_summary)
rank_df = stage1_summary.reset_index()
BEST_CONFIG_NAME = rank_df.iloc[0]['Exp']
SECOND_CONFIG_NAME = rank_df.iloc[1]['Exp'] if len(rank_df) > 1 else rank_df.iloc[0]['Exp']
print('BEST_CONFIG_NAME (A):', BEST_CONFIG_NAME)
print('SECOND_CONFIG_NAME (B):', SECOND_CONFIG_NAME)
# Out:
#                                       AUC               AUPRC            \
#                                      mean       std      mean       std
# Exp
# Baseline_head_two_layer          0.888905  0.010843  0.591086  0.039723
# Baseline_head_two_layer_lowdrop  0.878580  0.019915  0.586344  0.013734
# Baseline_head_two_layer_lowlr    0.876065  0.012914  0.586135  0.027603
# Baseline_head_default            0.799527  0.014230  0.459669  0.040769
#
#                                        F1                 MCC            \
#                                      mean       std      mean       std
# Exp
# Baseline_head_two_layer          0.455672  0.072013  0.408537  0.072036
# Baseline_head_two_layer_lowdrop  0.469786  0.063145  0.435094  0.076819
# Baseline_head_two_layer_lowlr    0.441441  0.021803  0.389785  0.021892
# Baseline_head_default            0.388240  0.031131  0.326162  0.033980
#
#                                     Brier                 ECE
#                                      mean       std      mean       std
# Exp
# Baseline_head_two_layer          0.064982  0.008992  0.056987  0.011225
# Baseline_head_two_layer_lowdrop  0.067062  0.006070  0.052769  0.010226
# Baseline_head_two_layer_lowlr    0.064203  0.011430  0.048729  0.020188
# Baseline_head_default            0.078728  0.006006  0.064222  0.012332
# BEST_CONFIG_NAME (A):     Baseline_head_two_layer
# Name: 0, dtype: object
# SECOND_CONFIG_NAME (B):     Baseline_head_two_layer_lowdrop
# Name: 1, dtype: object

# %%
# Stage 2 融合配置：Fusion_PSSMxxx 指将 ProteinBERT 全局表示与对应维度 PSSM 特征进行 late-fusion
FUSION_CFG = FusionTrainConfig(
    seq_len=512,
    batch_size=8,
    frozen_epochs=6,
    unfrozen_epochs=12,
    frozen_lr=1e-4,
    unfrozen_lr=2e-5,
    pssm_dropout=0.3,
    global_dropout=0.3,
    pssm_hidden_dim=128,
    global_hidden_dim=128,
    global_bottleneck_dim=64,
    fusion_hidden_dim=128,
    use_hidden_global_concat=True,
)
print('Fusion config ready.')
# Out:
# Fusion config ready.

# %%
# Exp 2.1 Fusion_PSSM110（额外加入：仅 RPSSM(110) 融合）
for seed in SEEDS:
    print(f'Exp2.1 seed={seed}')
    m = run_fusion(seed=seed, dim='110', cfg=FUSION_CFG)
    record_result('Fusion_PSSM110', seed, m, extra={'Stage': '2', 'dim': 110, 'best_ref': BEST_CONFIG_NAME})
to_results_df().query("Exp == 'Fusion_PSSM110'")
# Out:
# Exp2.1 seed=0
# Exp2.1 seed=11
# Exp2.1 seed=22
# Exp2.1 seed=33
# Exp2.1 seed=44
#                Exp  Seed       AUC     AUPRC        F1       MCC     Brier  \
# 4   Fusion_PSSM110     0  0.897929  0.643554  0.553191  0.517163  0.056787
# 9   Fusion_PSSM110    11  0.886686  0.617604  0.550725  0.513536  0.063103
# 14  Fusion_PSSM110    22  0.880473  0.659372  0.472222  0.424360  0.060551
# 19  Fusion_PSSM110    33  0.893639  0.640345  0.487805  0.456968  0.063637
# 24  Fusion_PSSM110    44  0.889793  0.566851  0.493151  0.450536  0.089696
#
#          ECE  Threshold Stage head_type    dim  \
# 4   0.043278       0.55     2       NaN  110.0
# 9   0.059579       0.35     2       NaN  110.0
# 14  0.055715       0.30     2       NaN  110.0
# 19  0.049991       0.15     2       NaN  110.0
# 24  0.097507       0.50     2       NaN  110.0
#
#                                              best_ref
# 4       Baseline_head_two_layer
# Name: 0, dtype: ob...
# 9       Baseline_head_two_layer
# Name: 0, dtype: ob...
# 14      Baseline_head_two_layer
# Name: 0, dtype: ob...
# 19      Baseline_head_two_layer
# Name: 0, dtype: ob...
# 24      Baseline_head_two_layer
# Name: 0, dtype: ob...

# %%
# Exp 2.2 Fusion_PSSM310（ProteinBERT + 310维PSSM融合）
for seed in SEEDS:
    print(f'Exp2.2 seed={seed}')
    m = run_fusion(seed=seed, dim='310', cfg=FUSION_CFG)
    record_result('Fusion_PSSM310', seed, m, extra={'Stage': '2', 'dim': 310, 'best_ref': BEST_CONFIG_NAME})
to_results_df().query("Exp == 'Fusion_PSSM310'")
# Out:
# Exp2.2 seed=0
# Exp2.2 seed=11
# Exp2.2 seed=22
# Exp2.2 seed=33
# Exp2.2 seed=44
#                Exp  Seed       AUC     AUPRC        F1       MCC     Brier  \
# 5   Fusion_PSSM310     0  0.902663  0.671245  0.529412  0.487310  0.056796
# 11  Fusion_PSSM310    11  0.903698  0.568502  0.521739  0.479506  0.066531
# 17  Fusion_PSSM310    22  0.909763  0.661862  0.562500  0.521198  0.067481
# 23  Fusion_PSSM310    33  0.898669  0.599911  0.472222  0.424360  0.069120
# 29  Fusion_PSSM310    44  0.901036  0.605519  0.465116  0.434500  0.055468
#
#          ECE  Threshold Stage head_type    dim  \
# 5   0.053417       0.25     2       NaN  310.0
# 11  0.062710       0.30     2       NaN  310.0
# 17  0.065166       0.55     2       NaN  310.0
# 23  0.056419       0.25     2       NaN  310.0
# 29  0.049872       0.05     2       NaN  310.0
#
#                                              best_ref
# 5       Baseline_head_two_layer
# Name: 0, dtype: ob...
# 11      Baseline_head_two_layer
# Name: 0, dtype: ob...
# 17      Baseline_head_two_layer
# Name: 0, dtype: ob...
# 23      Baseline_head_two_layer
# Name: 0, dtype: ob...
# 29      Baseline_head_two_layer
# Name: 0, dtype: ob...

# %%
# Exp 2.3 Fusion_PSSM710（ProteinBERT + 710维PSSM融合）
for seed in SEEDS:
    print(f'Exp2.3 seed={seed}')
    m = run_fusion(seed=seed, dim='710', cfg=FUSION_CFG)
    record_result('Fusion_PSSM710', seed, m, extra={'Stage': '2', 'dim': 710, 'best_ref': BEST_CONFIG_NAME})
to_results_df().query("Exp == 'Fusion_PSSM710'")
# Out:
# Exp2.3 seed=0
# Exp2.3 seed=11
# Exp2.3 seed=22
# Exp2.3 seed=33
# Exp2.3 seed=44
#                Exp  Seed       AUC     AUPRC        F1       MCC     Brier  \
# 6   Fusion_PSSM710     0  0.910799  0.628328  0.625000  0.593366  0.055124
# 13  Fusion_PSSM710    11  0.913609  0.667711  0.545455  0.498165  0.051487
# 20  Fusion_PSSM710    22  0.904290  0.683470  0.535714  0.487139  0.059565
# 27  Fusion_PSSM710    33  0.897041  0.570110  0.537313  0.495364  0.067843
# 34  Fusion_PSSM710    44  0.908284  0.644682  0.461538  0.437981  0.070470
#
#          ECE  Threshold Stage head_type    dim  \
# 6   0.038626       0.50     2       NaN  710.0
# 13  0.034559       0.25     2       NaN  710.0
# 20  0.051636       0.45     2       NaN  710.0
# 27  0.055949       0.30     2       NaN  710.0
# 34  0.071461       0.20     2       NaN  710.0
#
#                                              best_ref
# 6       Baseline_head_two_layer
# Name: 0, dtype: ob...
# 13      Baseline_head_two_layer
# Name: 0, dtype: ob...
# 20      Baseline_head_two_layer
# Name: 0, dtype: ob...
# 27      Baseline_head_two_layer
# Name: 0, dtype: ob...
# 34      Baseline_head_two_layer
# Name: 0, dtype: ob...

# %%
# Exp 2.4 Fusion_PSSM1110（ProteinBERT + 1110维PSSM融合）
for seed in SEEDS:
    print(f'Exp2.4 seed={seed}')
    m = run_fusion(seed=seed, dim='1110', cfg=FUSION_CFG)
    record_result('Fusion_PSSM1110', seed, m, extra={'Stage': '2', 'dim': 1110, 'best_ref': BEST_CONFIG_NAME})
to_results_df().query("Exp == 'Fusion_PSSM1110'")
# Out:
# Exp2.4 seed=0
# Exp2.4 seed=11
# Exp2.4 seed=22
# Exp2.4 seed=33
# Exp2.4 seed=44
#                 Exp  Seed       AUC     AUPRC        F1       MCC     Brier  \
# 5   Fusion_PSSM1110     0  0.926331  0.705027  0.620690  0.582259  0.056287
# 13  Fusion_PSSM1110    11  0.935207  0.643265  0.580645  0.540000  0.057036
# 21  Fusion_PSSM1110    22  0.945266  0.751913  0.678571  0.645911  0.043013
# 29  Fusion_PSSM1110    33  0.914941  0.607432  0.545455  0.503686  0.070745
# 37  Fusion_PSSM1110    44  0.941124  0.692673  0.560000  0.534071  0.056165
#
#          ECE  Threshold Stage head_type     dim  \
# 5   0.052527       0.45     2       NaN  1110.0
# 13  0.034540       0.30     2       NaN  1110.0
# 21  0.035217       0.20     2       NaN  1110.0
# 29  0.059431       0.45     2       NaN  1110.0
# 37  0.037230       0.20     2       NaN  1110.0
#
#                                              best_ref
# 5       Baseline_head_two_layer
# Name: 0, dtype: ob...
# 13      Baseline_head_two_layer
# Name: 0, dtype: ob...
# 21      Baseline_head_two_layer
# Name: 0, dtype: ob...
# 29      Baseline_head_two_layer
# Name: 0, dtype: ob...
# 37      Baseline_head_two_layer
# Name: 0, dtype: ob...

# %%
# Exp 3.1 Ablation_RPSSM_110（仅特征、无ProteinBERT）
for seed in SEEDS:
    print(f'Exp3.1 seed={seed}')
    m = run_pssm_only(seed=seed, dim='110')
    record_result('Ablation_RPSSM_110', seed, m, extra={'Stage': '3', 'dim': 110, 'fs': 'none'})
to_results_df().query("Exp == 'Ablation_RPSSM_110'")
# Out:
# Exp3.1 seed=0
# Exp3.1 seed=11
# Exp3.1 seed=22
# Exp3.1 seed=33
# Exp3.1 seed=44
#                    Exp  Seed       AUC     AUPRC        F1       MCC  \
# 0   Ablation_RPSSM_110     0  0.755030  0.276326  0.285714  0.202199
# 9   Ablation_RPSSM_110    11  0.752515  0.241930  0.290323  0.210000
# 18  Ablation_RPSSM_110    22  0.747929  0.275975  0.300000  0.244804
# 27  Ablation_RPSSM_110    33  0.758432  0.271897  0.289855  0.207270
# 36  Ablation_RPSSM_110    44  0.746006  0.243972  0.271605  0.185164
#
#        Brier       ECE  Threshold Stage head_type    dim best_ref    fs
# 0   0.107601  0.092869       0.35     3       NaN  110.0      NaN  none
# 9   0.116171  0.096755       0.50     3       NaN  110.0      NaN  none
# 18  0.108589  0.091246       0.15     3       NaN  110.0      NaN  none
# 27  0.114578  0.087758       0.40     3       NaN  110.0      NaN  none
# 36  0.114592  0.102062       0.35     3       NaN  110.0      NaN  none

# %%
# Exp 3.2 Ablation_RPSSM_310（仅特征、无ProteinBERT）
for seed in SEEDS:
    print(f'Exp3.2 seed={seed}')
    m = run_pssm_only(seed=seed, dim='310')
    record_result('Ablation_RPSSM_310', seed, m, extra={'Stage': '3', 'dim': 310, 'fs': 'none'})
to_results_df().query("Exp == 'Ablation_RPSSM_310'")
# Out:
# Exp3.2 seed=0
# Exp3.2 seed=11
# Exp3.2 seed=22
# Exp3.2 seed=33
# Exp3.2 seed=44
#                    Exp  Seed       AUC     AUPRC        F1       MCC  \
# 1   Ablation_RPSSM_310     0  0.774556  0.298744  0.338462  0.264200
# 11  Ablation_RPSSM_310    11  0.752515  0.265955  0.339623  0.272271
# 21  Ablation_RPSSM_310    22  0.759615  0.256178  0.250000  0.158319
# 31  Ablation_RPSSM_310    33  0.752959  0.275568  0.282051  0.197806
# 41  Ablation_RPSSM_310    44  0.785799  0.294399  0.333333  0.259641
#
#        Brier       ECE  Threshold Stage head_type    dim best_ref    fs
# 1   0.155594  0.159812       0.75     3       NaN  310.0      NaN  none
# 11  0.145624  0.165334       0.85     3       NaN  310.0      NaN  none
# 21  0.156438  0.160834       0.45     3       NaN  310.0      NaN  none
# 31  0.156083  0.170176       0.50     3       NaN  310.0      NaN  none
# 41  0.142755  0.146012       0.80     3       NaN  310.0      NaN  none

# %%
# Exp 3.3 Ablation_RPSSM_710（仅特征、无ProteinBERT）
for seed in SEEDS:
    print(f'Exp3.3 seed={seed}')
    m = run_pssm_only(seed=seed, dim='710')
    record_result('Ablation_RPSSM_710', seed, m, extra={'Stage': '3', 'dim': 710, 'fs': 'none'})
to_results_df().query("Exp == 'Ablation_RPSSM_710'")
# Out:
# Exp3.3 seed=0
# Exp3.3 seed=11
# Exp3.3 seed=22
# Exp3.3 seed=33
# Exp3.3 seed=44
#                    Exp  Seed       AUC     AUPRC        F1       MCC  \
# 2   Ablation_RPSSM_710     0  0.811243  0.395224  0.351351  0.281070
# 13  Ablation_RPSSM_710    11  0.798817  0.382960  0.382979  0.330645
# 24  Ablation_RPSSM_710    22  0.802663  0.374148  0.300000  0.222062
# 35  Ablation_RPSSM_710    33  0.804142  0.337437  0.333333  0.259641
# 46  Ablation_RPSSM_710    44  0.831805  0.398308  0.379310  0.312175
#
#        Brier       ECE  Threshold Stage head_type    dim best_ref    fs
# 2   0.125969  0.124631       0.45     3       NaN  710.0      NaN  none
# 13  0.136547  0.142521       0.95     3       NaN  710.0      NaN  none
# 24  0.136859  0.131975       0.75     3       NaN  710.0      NaN  none
# 35  0.138166  0.142279       0.75     3       NaN  710.0      NaN  none
# 46  0.122777  0.119585       0.80     3       NaN  710.0      NaN  none

# %%
# Exp 3.4 Ablation_RPSSM_1110（仅特征、无ProteinBERT）
for seed in SEEDS:
    print(f'Exp3.4 seed={seed}')
    m = run_pssm_only(seed=seed, dim='1110')
    record_result('Ablation_RPSSM_1110', seed, m, extra={'Stage': '3', 'dim': 1110, 'fs': 'none'})
to_results_df().query("Exp == 'Ablation_RPSSM_1110'")
# Out:
# Exp3.4 seed=0
# Exp3.4 seed=11
# Exp3.4 seed=22
# Exp3.4 seed=33
# Exp3.4 seed=44
#                     Exp  Seed       AUC     AUPRC        F1       MCC  \
# 1   Ablation_RPSSM_1110     0  0.875296  0.476072  0.417910  0.356536
# 13  Ablation_RPSSM_1110    11  0.857988  0.451199  0.430380  0.381319
# 25  Ablation_RPSSM_1110    22  0.864941  0.466223  0.447761  0.391243
# 37  Ablation_RPSSM_1110    33  0.856953  0.430368  0.318182  0.268626
# 49  Ablation_RPSSM_1110    44  0.893343  0.491126  0.470588  0.418587
#
#        Brier       ECE  Threshold Stage head_type     dim best_ref    fs
# 1   0.106996  0.114275       0.50     3       NaN  1110.0      NaN  none
# 13  0.108893  0.106237       0.40     3       NaN  1110.0      NaN  none
# 25  0.115857  0.118269       0.65     3       NaN  1110.0      NaN  none
# 37  0.121021  0.127670       0.95     3       NaN  1110.0      NaN  none
# 49  0.100599  0.104541       0.55     3       NaN  1110.0      NaN  none

# %%
# Exp 3.5 Ablation_RPSSM_310_FS（ANOVA+IFS 近似：在 train 内 SelectKBest）
for seed in SEEDS:
    print(f'Exp3.5 seed={seed}')
    m = run_pssm_only(seed=seed, dim='310', top_k=150)
    record_result('Ablation_RPSSM_310_FS', seed, m, extra={'Stage': '3', 'dim': 310, 'fs': 'SelectKBest_f_classif_top150'})
to_results_df().query("Exp == 'Ablation_RPSSM_310_FS'")
# Out:
# Exp3.5 seed=0
# Exp3.5 seed=11
# Exp3.5 seed=22
# Exp3.5 seed=33
# Exp3.5 seed=44
#                       Exp  Seed       AUC     AUPRC        F1       MCC  \
# 3   Ablation_RPSSM_310_FS     0  0.773225  0.289457  0.280000  0.201979
# 16  Ablation_RPSSM_310_FS    11  0.758876  0.243776  0.318841  0.241300
# 29  Ablation_RPSSM_310_FS    22  0.783876  0.301332  0.318841  0.241300
# 42  Ablation_RPSSM_310_FS    33  0.759172  0.254059  0.318841  0.241300
# 55  Ablation_RPSSM_310_FS    44  0.757544  0.256145  0.313253  0.238036
#
#        Brier       ECE  Threshold Stage head_type    dim best_ref  \
# 3   0.097781  0.082583       0.20     3       NaN  310.0      NaN
# 16  0.111490  0.093356       0.40     3       NaN  310.0      NaN
# 29  0.099021  0.080733       0.35     3       NaN  310.0      NaN
# 42  0.115284  0.104807       0.45     3       NaN  310.0      NaN
# 55  0.108353  0.096100       0.30     3       NaN  310.0      NaN
#
#                               fs
# 3   SelectKBest_f_classif_top150
# 16  SelectKBest_f_classif_top150
# 29  SelectKBest_f_classif_top150
# 42  SelectKBest_f_classif_top150
# 55  SelectKBest_f_classif_top150

# %%
# Exp 3.6 Ablation_RPSSM_710_FS（ANOVA+IFS 近似：在 train 内 SelectKBest）
for seed in SEEDS:
    print(f'Exp3.6 seed={seed}')
    m = run_pssm_only(seed=seed, dim='710', top_k=250)
    record_result('Ablation_RPSSM_710_FS', seed, m, extra={'Stage': '3', 'dim': 710, 'fs': 'SelectKBest_f_classif_top250'})
to_results_df().query("Exp == 'Ablation_RPSSM_710_FS'")
# Out:
# Exp3.6 seed=0
# Exp3.6 seed=11
# Exp3.6 seed=22
# Exp3.6 seed=33
# Exp3.6 seed=44
#                       Exp  Seed       AUC     AUPRC        F1       MCC  \
# 5   Ablation_RPSSM_710_FS     0  0.855473  0.410499  0.392857  0.328368
# 19  Ablation_RPSSM_710_FS    11  0.829586  0.362764  0.363636  0.296701
# 33  Ablation_RPSSM_710_FS    22  0.857396  0.426873  0.395604  0.350912
# 47  Ablation_RPSSM_710_FS    33  0.850148  0.360392  0.353982  0.319643
# 61  Ablation_RPSSM_710_FS    44  0.825740  0.383886  0.324324  0.316228
#
#        Brier       ECE  Threshold Stage head_type    dim best_ref  \
# 5   0.099938  0.095143       0.60     3       NaN  710.0      NaN
# 19  0.108888  0.105205       0.75     3       NaN  710.0      NaN
# 33  0.098726  0.085197       0.10     3       NaN  710.0      NaN
# 47  0.106483  0.106913       0.05     3       NaN  710.0      NaN
# 61  0.090459  0.090867       0.90     3       NaN  710.0      NaN
#
#                               fs
# 5   SelectKBest_f_classif_top250
# 19  SelectKBest_f_classif_top250
# 33  SelectKBest_f_classif_top250
# 47  SelectKBest_f_classif_top250
# 61  SelectKBest_f_classif_top250

# %%
# Exp 3.7 Ablation_RPSSM_1110_FS（ANOVA+IFS 近似：在 train 内 SelectKBest）
for seed in SEEDS:
    print(f'Exp3.7 seed={seed}')
    m = run_pssm_only(seed=seed, dim='1110', top_k=350)
    record_result('Ablation_RPSSM_1110_FS', seed, m, extra={'Stage': '3', 'dim': 1110, 'fs': 'SelectKBest_f_classif_top350'})
to_results_df().query("Exp == 'Ablation_RPSSM_1110_FS'")
# Out:
# Exp3.7 seed=0
# Exp3.7 seed=11
# Exp3.7 seed=22
# Exp3.7 seed=33
# Exp3.7 seed=44
#                        Exp  Seed       AUC     AUPRC        F1       MCC  \
# 2   Ablation_RPSSM_1110_FS     0  0.887278  0.518481  0.357143  0.323103
# 17  Ablation_RPSSM_1110_FS    11  0.865828  0.442901  0.480000  0.437234
# 32  Ablation_RPSSM_1110_FS    22  0.875000  0.475716  0.439024  0.395668
# 47  Ablation_RPSSM_1110_FS    33  0.870858  0.386911  0.396040  0.364499
# 62  Ablation_RPSSM_1110_FS    44  0.867604  0.482359  0.435897  0.387012
#
#        Brier       ECE  Threshold Stage head_type     dim best_ref  \
# 2   0.078597  0.081621       0.05     3       NaN  1110.0      NaN
# 17  0.091385  0.074149       0.30     3       NaN  1110.0      NaN
# 32  0.097555  0.095260       0.25     3       NaN  1110.0      NaN
# 47  0.104707  0.100061       0.10     3       NaN  1110.0      NaN
# 62  0.089212  0.089656       0.35     3       NaN  1110.0      NaN
#
#                               fs
# 2   SelectKBest_f_classif_top350
# 17  SelectKBest_f_classif_top350
# 32  SelectKBest_f_classif_top350
# 47  SelectKBest_f_classif_top350
# 62  SelectKBest_f_classif_top350

# %%
# Stage 4 交互检查说明：
# 这里的 A/B 分别对应 Stage1 里选出的最佳/次优基线配置名。
# 当前采用同一融合架构（run_finetune_with_pssm）；A/B 主要作为“基线来源标签”，用于检查排序一致性。
print('A (best baseline):', BEST_CONFIG_NAME)
print('B (runner-up baseline):', SECOND_CONFIG_NAME)
# Out:
# A (best baseline):     Baseline_head_two_layer
# Name: 0, dtype: object
# B (runner-up baseline):     Baseline_head_two_layer_lowdrop
# Name: 1, dtype: object

# %%
# Exp 4.1 Fusion_PSSM710_A
for seed in SEEDS:
    print(f'Exp4.1 seed={seed}')
    m = run_fusion(seed=seed, dim='710', cfg=FUSION_CFG)
    record_result('Fusion_PSSM710_A', seed, m, extra={'Stage': '4', 'ref_baseline': BEST_CONFIG_NAME})
to_results_df().query("Exp == 'Fusion_PSSM710_A'")
# Out:
# Exp4.1 seed=0
# Exp4.1 seed=11
# Exp4.1 seed=22
# Exp4.1 seed=33
# Exp4.1 seed=44
#                  Exp  Seed       AUC     AUPRC        F1       MCC     Brier  \
# 15  Fusion_PSSM710_A     0  0.914793  0.643208  0.603774  0.563449  0.061485
# 31  Fusion_PSSM710_A    11  0.912574  0.619936  0.595745  0.563792  0.055342
# 47  Fusion_PSSM710_A    22  0.897189  0.557738  0.526316  0.476600  0.070833
# 63  Fusion_PSSM710_A    33  0.913314  0.644501  0.469136  0.432049  0.059676
# 79  Fusion_PSSM710_A    44  0.910947  0.663316  0.566667  0.522699  0.050125
#
#          ECE  Threshold Stage head_type  dim best_ref   fs  \
# 15  0.056540       0.55     4       NaN  NaN      NaN  NaN
# 31  0.045207       0.60     4       NaN  NaN      NaN  NaN
# 47  0.062913       0.55     4       NaN  NaN      NaN  NaN
# 63  0.050884       0.15     4       NaN  NaN      NaN  NaN
# 79  0.036953       0.25     4       NaN  NaN      NaN  NaN
#
#                                          ref_baseline
# 15      Baseline_head_two_layer
# Name: 0, dtype: ob...
# 31      Baseline_head_two_layer
# Name: 0, dtype: ob...
# 47      Baseline_head_two_layer
# Name: 0, dtype: ob...
# 63      Baseline_head_two_layer
# Name: 0, dtype: ob...
# 79      Baseline_head_two_layer
# Name: 0, dtype: ob...

# %%
# Exp 4.2 Fusion_PSSM710_B
for seed in SEEDS:
    print(f'Exp4.2 seed={seed}')
    m = run_fusion(seed=seed, dim='710', cfg=FUSION_CFG)
    record_result('Fusion_PSSM710_B', seed, m, extra={'Stage': '4', 'ref_baseline': SECOND_CONFIG_NAME})
to_results_df().query("Exp == 'Fusion_PSSM710_B'")
# Out:
# Exp4.2 seed=0
# Exp4.2 seed=11
# Exp4.2 seed=22
# Exp4.2 seed=33
# Exp4.2 seed=44
#                  Exp  Seed       AUC     AUPRC        F1       MCC     Brier  \
# 16  Fusion_PSSM710_B     0  0.922633  0.698321  0.692308  0.661538  0.046274
# 33  Fusion_PSSM710_B    11  0.909763  0.653540  0.487805  0.456968  0.056057
# 50  Fusion_PSSM710_B    22  0.889645  0.586040  0.555556  0.509720  0.064013
# 67  Fusion_PSSM710_B    33  0.879882  0.596608  0.475000  0.437916  0.072762
# 84  Fusion_PSSM710_B    44  0.909911  0.674519  0.545455  0.503686  0.048130
#
#          ECE  Threshold Stage head_type  dim best_ref   fs  \
# 16  0.044274       0.40     4       NaN  NaN      NaN  NaN
# 33  0.047992       0.10     4       NaN  NaN      NaN  NaN
# 50  0.048266       0.55     4       NaN  NaN      NaN  NaN
# 67  0.076032       0.25     4       NaN  NaN      NaN  NaN
# 84  0.023479       0.20     4       NaN  NaN      NaN  NaN
#
#                                          ref_baseline
# 16      Baseline_head_two_layer_lowdrop
# Name: 1, d...
# 33      Baseline_head_two_layer_lowdrop
# Name: 1, d...
# 50      Baseline_head_two_layer_lowdrop
# Name: 1, d...
# 67      Baseline_head_two_layer_lowdrop
# Name: 1, d...
# 84      Baseline_head_two_layer_lowdrop
# Name: 1, d...

# %%
# Exp 4.3 Fusion_PSSM1110_A
for seed in SEEDS:
    print(f'Exp4.3 seed={seed}')
    m = run_fusion(seed=seed, dim='1110', cfg=FUSION_CFG)
    record_result('Fusion_PSSM1110_A', seed, m, extra={'Stage': '4', 'ref_baseline': BEST_CONFIG_NAME})
to_results_df().query("Exp == 'Fusion_PSSM1110_A'")
# Out:
# Exp4.3 seed=0
# Exp4.3 seed=11
# Exp4.3 seed=22
# Exp4.3 seed=33
# Exp4.3 seed=44
#                   Exp  Seed       AUC     AUPRC        F1       MCC     Brier  \
# 13  Fusion_PSSM1110_A     0  0.920414  0.679727  0.615385  0.576923  0.060216
# 31  Fusion_PSSM1110_A    11  0.927811  0.624061  0.571429  0.532635  0.059214
# 49  Fusion_PSSM1110_A    22  0.929586  0.720247  0.634921  0.602907  0.046613
# 67  Fusion_PSSM1110_A    33  0.922781  0.621606  0.513514  0.476340  0.054736
# 85  Fusion_PSSM1110_A    44  0.935059  0.649939  0.505747  0.488565  0.059747
#
#          ECE  Threshold Stage head_type  dim best_ref   fs  \
# 13  0.063651       0.55     4       NaN  NaN      NaN  NaN
# 31  0.049211       0.55     4       NaN  NaN      NaN  NaN
# 49  0.025568       0.25     4       NaN  NaN      NaN  NaN
# 67  0.037041       0.10     4       NaN  NaN      NaN  NaN
# 85  0.039314       0.10     4       NaN  NaN      NaN  NaN
#
#                                          ref_baseline
# 13      Baseline_head_two_layer
# Name: 0, dtype: ob...
# 31      Baseline_head_two_layer
# Name: 0, dtype: ob...
# 49      Baseline_head_two_layer
# Name: 0, dtype: ob...
# 67      Baseline_head_two_layer
# Name: 0, dtype: ob...
# 85      Baseline_head_two_layer
# Name: 0, dtype: ob...

# %%
# Exp 4.4 Fusion_PSSM1110_B
for seed in SEEDS:
    print(f'Exp4.4 seed={seed}')
    m = run_fusion(seed=seed, dim='1110', cfg=FUSION_CFG)
    record_result('Fusion_PSSM1110_B', seed, m, extra={'Stage': '4', 'ref_baseline': SECOND_CONFIG_NAME})
to_results_df().query("Exp == 'Fusion_PSSM1110_B'")
# Out:
# Exp4.4 seed=0
# Exp4.4 seed=11
# Exp4.4 seed=22
# Exp4.4 seed=33
# Exp4.4 seed=44
#                   Exp  Seed       AUC     AUPRC        F1       MCC     Brier  \
# 14  Fusion_PSSM1110_B     0  0.934763  0.687410  0.627451  0.591135  0.049619
# 33  Fusion_PSSM1110_B    11  0.920858  0.673500  0.612245  0.577360  0.051576
# 52  Fusion_PSSM1110_B    22  0.918195  0.707798  0.644068  0.609110  0.048288
# 71  Fusion_PSSM1110_B    33  0.930769  0.686040  0.550000  0.548322  0.055771
# 90  Fusion_PSSM1110_B    44  0.920266  0.688845  0.523077  0.476849  0.057722
#
#          ECE  Threshold Stage head_type  dim best_ref   fs  \
# 14  0.039051       0.40     4       NaN  NaN      NaN  NaN
# 33  0.037412       0.40     4       NaN  NaN      NaN  NaN
# 52  0.030279       0.30     4       NaN  NaN      NaN  NaN
# 71  0.037192       0.85     4       NaN  NaN      NaN  NaN
# 90  0.049783       0.30     4       NaN  NaN      NaN  NaN
#
#                                          ref_baseline
# 14      Baseline_head_two_layer_lowdrop
# Name: 1, d...
# 33      Baseline_head_two_layer_lowdrop
# Name: 1, d...
# 52      Baseline_head_two_layer_lowdrop
# Name: 1, d...
# 71      Baseline_head_two_layer_lowdrop
# Name: 1, d...
# 90      Baseline_head_two_layer_lowdrop
# Name: 1, d...

# %%
# 汇总：全部实验明细
exp_df = to_results_df()
exp_df
# Out:
#                        Exp  Seed       AUC     AUPRC        F1       MCC  \
# 0       Ablation_RPSSM_110     0  0.755030  0.276326  0.285714  0.202199
# 1      Ablation_RPSSM_1110     0  0.875296  0.476072  0.417910  0.356536
# 2   Ablation_RPSSM_1110_FS     0  0.887278  0.518481  0.357143  0.323103
# 3       Ablation_RPSSM_310     0  0.774556  0.298744  0.338462  0.264200
# 4    Ablation_RPSSM_310_FS     0  0.773225  0.289457  0.280000  0.201979
# ..                     ...   ...       ...       ...       ...       ...
# 90       Fusion_PSSM1110_B    44  0.920266  0.688845  0.523077  0.476849
# 91          Fusion_PSSM310    44  0.901036  0.605519  0.465116  0.434500
# 92          Fusion_PSSM710    44  0.908284  0.644682  0.461538  0.437981
# 93        Fusion_PSSM710_A    44  0.910947  0.663316  0.566667  0.522699
# 94        Fusion_PSSM710_B    44  0.909911  0.674519  0.545455  0.503686
#
#        Brier       ECE  Threshold Stage head_type     dim  \
# 0   0.107601  0.092869       0.35     3       NaN   110.0
# 1   0.106996  0.114275       0.50     3       NaN  1110.0
# 2   0.078597  0.081621       0.05     3       NaN  1110.0
# 3   0.155594  0.159812       0.75     3       NaN   310.0
# 4   0.097781  0.082583       0.20     3       NaN   310.0
# ..       ...       ...        ...   ...       ...     ...
# 90  0.057722  0.049783       0.30     4       NaN     NaN
# 91  0.055468  0.049872       0.05     2       NaN   310.0
# 92  0.070470  0.071461       0.20     2       NaN   710.0
# 93  0.050125  0.036953       0.25     4       NaN     NaN
# 94  0.048130  0.023479       0.20     4       NaN     NaN
#
#                                              best_ref  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 90                                                NaN
# 91      Baseline_head_two_layer
# Name: 0, dtype: ob...
# 92      Baseline_head_two_layer
# Name: 0, dtype: ob...
# 93                                                NaN
# 94                                                NaN
#
#                               fs  \
# 0                           none
# 1                           none
# 2   SelectKBest_f_classif_top350
# 3                           none
# 4   SelectKBest_f_classif_top150
# ..                           ...
# 90                           NaN
# 91                           NaN
# 92                           NaN
# 93                           NaN
# 94                           NaN
#
#                                          ref_baseline
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 90      Baseline_head_two_layer_lowdrop
# Name: 1, d...
# 91                                                NaN
# 92                                                NaN
# 93      Baseline_head_two_layer
# Name: 0, dtype: ob...
# 94      Baseline_head_two_layer_lowdrop
# Name: 1, d...
#
# [95 rows x 15 columns]

# %%
# 汇总：按 Exp 统计 mean/std，按 AUPRC mean 排序
summary_df = summarize_by_exp(exp_df)
summary_df
# Out:
#                                       AUC               AUPRC            \
#                                      mean       std      mean       std
# Exp
# Fusion_PSSM1110_B                0.924970  0.007322  0.688719  0.012294
# Fusion_PSSM1110                  0.932574  0.012156  0.680062  0.056067
# Fusion_PSSM1110_A                0.927130  0.005775  0.659116  0.041478
# Fusion_PSSM710_B                 0.902367  0.017247  0.641806  0.048873
# Fusion_PSSM710                   0.906805  0.006444  0.638860  0.043857
# Fusion_PSSM710_A                 0.909763  0.007164  0.625740  0.041009
# Fusion_PSSM110                   0.889704  0.006661  0.625545  0.036040
# Fusion_PSSM310                   0.903166  0.004148  0.621408  0.043686
# Baseline_head_two_layer          0.888905  0.010843  0.591086  0.039723
# Baseline_head_two_layer_lowdrop  0.878580  0.019915  0.586344  0.013734
# Baseline_head_two_layer_lowlr    0.876065  0.012914  0.586135  0.027603
# Ablation_RPSSM_1110              0.869704  0.015105  0.462998  0.023326
# Ablation_RPSSM_1110_FS           0.873314  0.008552  0.461274  0.049481
# Baseline_head_default            0.799527  0.014230  0.459669  0.040769
# Ablation_RPSSM_710_FS            0.843669  0.014913  0.388883  0.029281
# Ablation_RPSSM_710               0.809734  0.013133  0.377616  0.024460
# Ablation_RPSSM_310               0.765089  0.014609  0.278169  0.018209
# Ablation_RPSSM_310_FS            0.766538  0.011610  0.268954  0.024943
# Ablation_RPSSM_110               0.751982  0.005082  0.262020  0.017509
#
#                                        F1                 MCC            \
#                                      mean       std      mean       std
# Exp
# Fusion_PSSM1110_B                0.591368  0.052178  0.560555  0.051796
# Fusion_PSSM1110                  0.597072  0.053639  0.561185  0.055029
# Fusion_PSSM1110_A                0.568199  0.058265  0.535474  0.054705
# Fusion_PSSM710_B                 0.551225  0.086297  0.513966  0.087940
# Fusion_PSSM710                   0.541004  0.057947  0.502403  0.056402
# Fusion_PSSM710_A                 0.552327  0.055531  0.511718  0.057203
# Fusion_PSSM110                   0.511419  0.037807  0.472512  0.040987
# Fusion_PSSM310                   0.510198  0.040965  0.469375  0.039851
# Baseline_head_two_layer          0.455672  0.072013  0.408537  0.072036
# Baseline_head_two_layer_lowdrop  0.469786  0.063145  0.435094  0.076819
# Baseline_head_two_layer_lowlr    0.441441  0.021803  0.389785  0.021892
# Ablation_RPSSM_1110              0.416964  0.058658  0.363262  0.057382
# Ablation_RPSSM_1110_FS           0.421621  0.046708  0.381503  0.041942
# Baseline_head_default            0.388240  0.031131  0.326162  0.033980
# Ablation_RPSSM_710_FS            0.366081  0.029515  0.322371  0.019715
# Ablation_RPSSM_710               0.349395  0.034367  0.281119  0.042914
# Ablation_RPSSM_310               0.308694  0.040634  0.230447  0.050022
# Ablation_RPSSM_310_FS            0.309955  0.016919  0.232783  0.017278
# Ablation_RPSSM_110               0.287499  0.010315  0.209888  0.021774
#
#                                     Brier                 ECE
#                                      mean       std      mean       std
# Exp
# Fusion_PSSM1110_B                0.052595  0.004026  0.038743  0.007032
# Fusion_PSSM1110                  0.056649  0.009813  0.043789  0.011436
# Fusion_PSSM1110_A                0.056105  0.005740  0.042957  0.014300
# Fusion_PSSM710_B                 0.057447  0.011082  0.048009  0.018715
# Fusion_PSSM710                   0.060898  0.008117  0.050446  0.014709
# Fusion_PSSM710_A                 0.059492  0.007707  0.050499  0.010028
# Fusion_PSSM110                   0.066755  0.013107  0.061214  0.021200
# Fusion_PSSM310                   0.063079  0.006426  0.057517  0.006363
# Baseline_head_two_layer          0.064982  0.008992  0.056987  0.011225
# Baseline_head_two_layer_lowdrop  0.067062  0.006070  0.052769  0.010226
# Baseline_head_two_layer_lowlr    0.064203  0.011430  0.048729  0.020188
# Ablation_RPSSM_1110              0.110673  0.007939  0.114198  0.009417
# Ablation_RPSSM_1110_FS           0.092291  0.009743  0.088150  0.010409
# Baseline_head_default            0.078728  0.006006  0.064222  0.012332
# Ablation_RPSSM_710_FS            0.100899  0.007240  0.096665  0.009293
# Ablation_RPSSM_710               0.132063  0.007137  0.132198  0.010303
# Ablation_RPSSM_310               0.151299  0.006575  0.160434  0.009048
# Ablation_RPSSM_310_FS            0.106386  0.007703  0.091516  0.009964
# Ablation_RPSSM_110               0.112306  0.003914  0.094138  0.005484

# %%
# 保存结果到 pssm_work/features/
os.makedirs(f'{WORK_ROOT}/features', exist_ok=True)
res_path = f'{WORK_ROOT}/features/full_plan_exp_results.csv'
sum_path = f'{WORK_ROOT}/features/full_plan_exp_summary.csv'
exp_df.to_csv(res_path, index=False)
summary_df.to_csv(sum_path)
print('saved:', res_path)
print('saved:', sum_path)
# Out:
# saved: /home/nemophila/projects/protein_bert/pssm_work/features/full_plan_exp_results.csv
# saved: /home/nemophila/projects/protein_bert/pssm_work/features/full_plan_exp_summary.csv

# %% [markdown]
# ## Stage 5: 严格防泄漏的 BERT + ANOVA + IFS(top-k)
#
# 本阶段新增实验用于回答：在 ProteinBERT+PSSM 融合中，先做 ANOVA 排序再做 IFS 选 top-k，是否比原始全维融合更好。
#
# **严格防泄漏约束**：
# - ANOVA 排序只在每个 seed 的训练子集（sub-train）上拟合；
# - IFS 的 k 选择只使用验证子集（sub-valid）表现，不看测试集；
# - 测试集仅在最终选定 k 后做一次评估。

# %%
# Exp 5.0 辅助函数：严格防泄漏的 ANOVA+IFS 融合训练
# 说明：
# 1) 先按 seed 将训练集划分为 sub-train/sub-valid；
# 2) 仅在 sub-train 上做 ANOVA(F-score) 排序；
# 3) 对 k_candidates 做 IFS：每个 k 都训练一次融合模型，用 sub-valid AUPRC 选最佳 k；
# 4) 返回最佳 k 对应的测试集指标。

from tensorflow import keras as tf_keras

def _split_train_valid_for_seed(train_df, seed):
    return train_test_split(train_df, test_size=0.1, stratify=train_df['label'], random_state=seed)

def _rank_features_by_anova(sub_train_df, feat_cols):
    X = sub_train_df[feat_cols].to_numpy(dtype=np.float32)
    y = sub_train_df['label'].astype(int).to_numpy()
    selector = SelectKBest(score_func=f_classif, k='all')
    selector.fit(X, y)
    scores = np.nan_to_num(selector.scores_, nan=-1e9, posinf=1e9, neginf=-1e9)
    order = np.argsort(scores)[::-1]
    ranked_cols = [feat_cols[i] for i in order]
    return ranked_cols

def _build_late_fusion_model_local(pretrained_model_generator, seq_len, pssm_dim, freeze_pretrained_layers, cfg):
    base_model = pretrained_model_generator.create_model(seq_len, compile=False, init_weights=True)
    if cfg.use_hidden_global_concat:
        base_model = get_model_with_hidden_layers_as_outputs(base_model)
    if freeze_pretrained_layers:
        for layer in base_model.layers:
            layer.trainable = False
    _, global_output = base_model.output

    pssm_input = tf_keras.layers.Input(shape=(pssm_dim,), name='pssm_input')
    global_branch = tf_keras.layers.LayerNormalization(name='global_ln_in')(global_output)
    global_branch = tf_keras.layers.Dense(cfg.global_bottleneck_dim, activation='relu', name='global_bottleneck')(global_branch)
    global_branch = tf_keras.layers.Dropout(cfg.global_dropout, name='global_drop')(global_branch)
    global_branch = tf_keras.layers.Dense(cfg.global_hidden_dim, activation='relu', name='global_dense')(global_branch)
    global_branch = tf_keras.layers.LayerNormalization(name='global_ln_out')(global_branch)

    pssm_branch = tf_keras.layers.LayerNormalization(name='pssm_ln')(pssm_input)
    pssm_branch = tf_keras.layers.Dense(cfg.pssm_hidden_dim, activation='relu', name='pssm_dense')(pssm_branch)
    pssm_branch = tf_keras.layers.Dropout(cfg.pssm_dropout, name='pssm_drop')(pssm_branch)
    pssm_branch = tf_keras.layers.LayerNormalization(name='pssm_ln_out')(pssm_branch)

    fused = tf_keras.layers.Concatenate(name='late_fusion')([global_branch, pssm_branch])
    fused = tf_keras.layers.Dense(cfg.fusion_hidden_dim, activation='relu', name='fusion_dense')(fused)
    fused = tf_keras.layers.Dropout(cfg.pssm_dropout, name='fusion_drop')(fused)
    out = tf_keras.layers.Dense(1, activation='sigmoid', name='output')(fused)
    return tf_keras.models.Model(inputs=base_model.inputs + [pssm_input], outputs=out)

def _encode_inputs(enc, seqs, seq_len, pssm_feats):
    tokenized, annotations = enc.encode_X(seqs, seq_len)
    return [tokenized, annotations, pssm_feats.astype(np.float32)]

def _train_eval_fusion_for_given_k(seed, sub_train_df, sub_valid_df, test_df, selected_cols, cfg):
    x_tr = sub_train_df[selected_cols].to_numpy(dtype=np.float32)
    x_va = sub_valid_df[selected_cols].to_numpy(dtype=np.float32)
    x_te = test_df[selected_cols].to_numpy(dtype=np.float32)

    scaler = StandardScaler()
    x_tr = scaler.fit_transform(x_tr)
    x_va = scaler.transform(x_va)
    x_te = scaler.transform(x_te)

    y_tr = sub_train_df['label'].astype(int).to_numpy()
    y_va = sub_valid_df['label'].astype(int).to_numpy()
    y_te = test_df['label'].astype(int).to_numpy()

    pmg, enc = load_pretrained_model(
        local_model_dump_dir=f'{PROJECT_ROOT}/proteinbert_models',
        download_model_dump_if_not_exists=True,
        validate_downloading=False,
    )

    X_tr = _encode_inputs(enc, sub_train_df['seq'].tolist(), cfg.seq_len, x_tr)
    X_va = _encode_inputs(enc, sub_valid_df['seq'].tolist(), cfg.seq_len, x_va)
    X_te = _encode_inputs(enc, test_df['seq'].tolist(), cfg.seq_len, x_te)

    callbacks = [tf_keras.callbacks.EarlyStopping(monitor='val_loss', patience=cfg.patience, restore_best_weights=True)]

    model = _build_late_fusion_model_local(
        pmg,
        seq_len=cfg.seq_len,
        pssm_dim=len(selected_cols),
        freeze_pretrained_layers=True,
        cfg=cfg,
    )
    model.compile(optimizer=tf_keras.optimizers.Adam(learning_rate=cfg.frozen_lr), loss='binary_crossentropy')
    model.fit(X_tr, y_tr, validation_data=(X_va, y_va), epochs=cfg.frozen_epochs, batch_size=cfg.batch_size, callbacks=callbacks, verbose=0)

    for layer in model.layers:
        layer.trainable = True
    model.compile(optimizer=tf_keras.optimizers.Adam(learning_rate=cfg.unfrozen_lr), loss='binary_crossentropy')
    model.fit(X_tr, y_tr, validation_data=(X_va, y_va), epochs=cfg.unfrozen_epochs, batch_size=cfg.batch_size, callbacks=callbacks, verbose=0)

    va_prob = model.predict(X_va, batch_size=cfg.batch_size, verbose=0).reshape(-1)
    thr = find_best_thr(y_va, va_prob)
    te_prob = model.predict(X_te, batch_size=cfg.batch_size, verbose=0).reshape(-1)

    metrics = evaluate_binary(y_te, te_prob, thr=thr)
    valid_auprc = float(average_precision_score(y_va, va_prob))
    return metrics, valid_auprc

def run_fusion_anova_ifs_no_leak(seed, dim, k_candidates, cfg):
    train_df, test_df, feat_cols = FEATURE_DATA[dim]
    sub_train_df, sub_valid_df = _split_train_valid_for_seed(train_df, seed)

    ranked_cols = _rank_features_by_anova(sub_train_df, feat_cols)
    k_candidates = [k for k in k_candidates if 1 <= k <= len(ranked_cols)]
    if len(k_candidates) == 0:
        raise ValueError(f'No valid k in {k_candidates} for dim={dim}')

    best = None
    for k in k_candidates:
        selected_cols = ranked_cols[:k]
        metrics, valid_auprc = _train_eval_fusion_for_given_k(
            seed=seed,
            sub_train_df=sub_train_df,
            sub_valid_df=sub_valid_df,
            test_df=test_df,
            selected_cols=selected_cols,
            cfg=cfg,
        )
        row = {'k': k, 'valid_AUPRC': valid_auprc, 'metrics': metrics}
        if (best is None) or (row['valid_AUPRC'] > best['valid_AUPRC']):
            best = row

    return best

# %%
# Exp 5.1 Fusion_PSSM710_ANOVA_IFS_noLeak
# 含义：ProteinBERT 与 710 维 PSSM 融合前，先在 sub-train 上 ANOVA 排序，再在 sub-valid 上 IFS 选最佳 top-k。
# 非重复点：这是“融合路径 + 严格防泄漏 + 自动选k”，不同于 Stage3 的 PSSM-only FS。

k_candidates_710 = [80, 120, 160, 200, 240, 280, 320]
for seed in SEEDS:
    print(f'Exp5.1 seed={seed}')
    best = run_fusion_anova_ifs_no_leak(seed=seed, dim='710', k_candidates=k_candidates_710, cfg=FUSION_CFG)
    record_result(
        'Fusion_PSSM710_ANOVA_IFS_noLeak',
        seed,
        best['metrics'],
        extra={
            'Stage': '5',
            'dim': 710,
            'fs': 'ANOVA+IFS_noLeak',
            'selected_k': int(best['k']),
            'valid_AUPRC_for_k_select': float(best['valid_AUPRC']),
        },
    )

to_results_df().query("Exp == 'Fusion_PSSM710_ANOVA_IFS_noLeak'")
# Out:
# Exp5.1 seed=0
# Exp5.1 seed=11
# Exp5.1 seed=22
# Exp5.1 seed=33
# Exp5.1 seed=44
#                                 Exp  Seed       AUC     AUPRC        F1  \
# 18  Fusion_PSSM710_ANOVA_IFS_noLeak     0  0.916568  0.655684  0.500000
# 38  Fusion_PSSM710_ANOVA_IFS_noLeak    11  0.901331  0.667572  0.524590
# 58  Fusion_PSSM710_ANOVA_IFS_noLeak    22  0.899112  0.651497  0.638298
# 78  Fusion_PSSM710_ANOVA_IFS_noLeak    33  0.912426  0.670072  0.576923
# 98  Fusion_PSSM710_ANOVA_IFS_noLeak    44  0.918195  0.665161  0.468085
#
#          MCC     Brier       ECE  Threshold Stage head_type    dim best_ref  \
# 18  0.491952  0.058395  0.050552       0.75     5       NaN  710.0      NaN
# 38  0.475717  0.050084  0.034120       0.20     5       NaN  710.0      NaN
# 58  0.610422  0.050044  0.031679       0.40     5       NaN  710.0      NaN
# 78  0.534615  0.053528  0.039220       0.50     5       NaN  710.0      NaN
# 98  0.451925  0.055977  0.050678       0.05     5       NaN  710.0      NaN
#
#                   fs ref_baseline  selected_k  valid_AUPRC_for_k_select
# 18  ANOVA+IFS_noLeak          NaN       280.0                  0.865886
# 38  ANOVA+IFS_noLeak          NaN       240.0                  0.884997
# 58  ANOVA+IFS_noLeak          NaN       200.0                  0.911481
# 78  ANOVA+IFS_noLeak          NaN       280.0                  0.692528
# 98  ANOVA+IFS_noLeak          NaN       160.0                  0.798432

# %%
# Exp 5.2 Fusion_PSSM1110_ANOVA_IFS_noLeak
# 含义：ProteinBERT 与 1110 维 PSSM 融合前，严格在 train/valid 内完成 ANOVA+IFS 选k，再评估 test。

k_candidates_1110 = [120, 200, 280, 360, 440, 520, 600]
for seed in SEEDS:
    print(f'Exp5.2 seed={seed}')
    best = run_fusion_anova_ifs_no_leak(seed=seed, dim='1110', k_candidates=k_candidates_1110, cfg=FUSION_CFG)
    record_result(
        'Fusion_PSSM1110_ANOVA_IFS_noLeak',
        seed,
        best['metrics'],
        extra={
            'Stage': '5',
            'dim': 1110,
            'fs': 'ANOVA+IFS_noLeak',
            'selected_k': int(best['k']),
            'valid_AUPRC_for_k_select': float(best['valid_AUPRC']),
        },
    )

to_results_df().query("Exp == 'Fusion_PSSM1110_ANOVA_IFS_noLeak'")
# Out:
# Exp5.2 seed=0
# Exp5.2 seed=11
# Exp5.2 seed=22
# Exp5.2 seed=33
# Exp5.2 seed=44
#                                  Exp  Seed       AUC     AUPRC        F1  \
# 14  Fusion_PSSM1110_ANOVA_IFS_noLeak     0  0.926627  0.695996  0.595745
# 35  Fusion_PSSM1110_ANOVA_IFS_noLeak    11  0.933580  0.677144  0.521739
# 56  Fusion_PSSM1110_ANOVA_IFS_noLeak    22  0.917899  0.679609  0.566667
# 77  Fusion_PSSM1110_ANOVA_IFS_noLeak    33  0.914497  0.585459  0.527778
# 98  Fusion_PSSM1110_ANOVA_IFS_noLeak    44  0.919231  0.716719  0.518519
#
#          MCC     Brier       ECE  Threshold Stage head_type     dim best_ref  \
# 14  0.563792  0.055125  0.049926       0.50     5       NaN  1110.0      NaN
# 35  0.479506  0.052855  0.044822       0.20     5       NaN  1110.0      NaN
# 56  0.522699  0.057001  0.041833       0.25     5       NaN  1110.0      NaN
# 77  0.490572  0.057734  0.037198       0.15     5       NaN  1110.0      NaN
# 98  0.493771  0.053211  0.045954       0.15     5       NaN  1110.0      NaN
#
#                   fs ref_baseline  selected_k  valid_AUPRC_for_k_select
# 14  ANOVA+IFS_noLeak          NaN       280.0                  0.905339
# 35  ANOVA+IFS_noLeak          NaN       440.0                  0.902198
# 56  ANOVA+IFS_noLeak          NaN       520.0                  0.907458
# 77  ANOVA+IFS_noLeak          NaN       600.0                  0.743731
# 98  ANOVA+IFS_noLeak          NaN       600.0                  0.843009

# %%
# Exp 5.3 融合 FS 新增实验对比（有意义且不重复）
# 对比项：
# - 原始融合：Fusion_PSSM710 / Fusion_PSSM1110
# - 严格防泄漏融合FS：Fusion_PSSM710_ANOVA_IFS_noLeak / Fusion_PSSM1110_ANOVA_IFS_noLeak

cmp_df = to_results_df().copy()
focus_exps = [
    'Fusion_PSSM710',
    'Fusion_PSSM1110',
    'Fusion_PSSM710_ANOVA_IFS_noLeak',
    'Fusion_PSSM1110_ANOVA_IFS_noLeak',
]
cmp_focus = cmp_df[cmp_df['Exp'].isin(focus_exps)].copy()
cmp_summary = summarize_by_exp(cmp_focus)
cmp_summary
# Out:
#                                        AUC               AUPRC            \
#                                       mean       std      mean       std
# Exp
# Fusion_PSSM1110                   0.932574  0.012156  0.680062  0.056067
# Fusion_PSSM1110_ANOVA_IFS_noLeak  0.922367  0.007675  0.670986  0.050359
# Fusion_PSSM710_ANOVA_IFS_noLeak   0.909527  0.008786  0.661997  0.008007
# Fusion_PSSM710                    0.906805  0.006444  0.638860  0.043857
#
#                                         F1                 MCC            \
#                                       mean       std      mean       std
# Exp
# Fusion_PSSM1110                   0.597072  0.053639  0.561185  0.055029
# Fusion_PSSM1110_ANOVA_IFS_noLeak  0.546089  0.033829  0.510068  0.034006
# Fusion_PSSM710_ANOVA_IFS_noLeak   0.541579  0.067124  0.512926  0.062292
# Fusion_PSSM710                    0.541004  0.057947  0.502403  0.056402
#
#                                      Brier                 ECE
#                                       mean       std      mean       std
# Exp
# Fusion_PSSM1110                   0.056649  0.009813  0.043789  0.011436
# Fusion_PSSM1110_ANOVA_IFS_noLeak  0.055185  0.002187  0.043946  0.004758
# Fusion_PSSM710_ANOVA_IFS_noLeak   0.053606  0.003663  0.041250  0.008972
# Fusion_PSSM710                    0.060898  0.008117  0.050446  0.014709

# %%
# Exp 5.4 保存包含 Stage5 的新结果文件（不覆盖原 full_plan 文件）
# 为便于回溯，另存一套带 noLeak FS 的结果。

exp_df_stage5 = to_results_df()
summary_df_stage5 = summarize_by_exp(exp_df_stage5)

os.makedirs(f'{WORK_ROOT}/features', exist_ok=True)
res_path_5 = f'{WORK_ROOT}/features/full_plan_exp_results_with_stage5_noleak.csv'
sum_path_5 = f'{WORK_ROOT}/features/full_plan_exp_summary_with_stage5_noleak.csv'
exp_df_stage5.to_csv(res_path_5, index=False)
summary_df_stage5.to_csv(sum_path_5)
print('saved:', res_path_5)
print('saved:', sum_path_5)
# Out:
# saved: /home/nemophila/projects/protein_bert/pssm_work/features/full_plan_exp_results_with_stage5_noleak.csv
# saved: /home/nemophila/projects/protein_bert/pssm_work/features/full_plan_exp_summary_with_stage5_noleak.csv

# %% [markdown]
# ## Stage 5 结果解读提示
#
# - 若 `Fusion_PSSM710_ANOVA_IFS_noLeak` 的 AUPRC/MCC 同时高于 `Fusion_PSSM710`，说明 710 维下存在有效冗余特征，筛选有益。
# - 若 `Fusion_PSSM1110_ANOVA_IFS_noLeak` 优于 `Fusion_PSSM1110`，说明 1110 维的高维噪声对融合有负担。
# - 若二者都无提升，说明当前融合头的“软特征选择”已足够，后续可不再投入 ANOVA+IFS。
